# %% [markdown]
# <a href="https://colab.research.google.com/github/Gokul7120/Python-/blob/main/Pandas_implementation_and_use_case.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Dataset Link: https://drive.google.com/file/d/1EceORi1NYzoixbs9C0fVB-6v1qiLet_Z/view?usp=sharing

# %% [markdown]
# #Use Case:
#
# The data scientists at BigMart have collected 2013 sales data for 1559 products across 10 stores in different cities. Also, certain attributes of each product and store have been defined. The aim is to build a predictive model and predict the sales of each product at a particular outlet.
#
# Using this model, BigMart will try to understand the properties of products and outlets which play a key role in increasing sales.
#
# Please note that the data may have missing values as some stores might not report all the data due to technical glitches. Hence, it will be required to treat them accordingly.
#
#
# **Data Dictionary**
#
# We have train (8523) and test (5681) data set, train data set has both input and output variable(s). You need to predict the sales for test data set.
#
#
# CSV containing the item outlet information with sales value
#
# ![](https://i.imgur.com/llSNZY7.jpg)

# %%
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# loading the dataset
path = '/content/drive/MyDrive/bigmart_data.csv'
df = pd.read_csv(path)
df.shape
# Out:
# (8523, 12)

# %%
# basic data exploration
df.head(3)
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility    Item_Type  \
# 0           FDA15         9.30          Low Fat         0.016047        Dairy
# 1           DRC01         5.92          Regular         0.019278  Soft Drinks
# 2           FDN15        17.50          Low Fat         0.016760         Meat
#
#    Item_MRP Outlet_Identifier  Outlet_Establishment_Year Outlet_Size  \
# 0  249.8092            OUT049                       1999      Medium
# 1   48.2692            OUT018                       2009      Medium
# 2  141.6180            OUT049                       1999      Medium
#
#   Outlet_Location_Type        Outlet_Type  Item_Outlet_Sales
# 0               Tier 1  Supermarket Type1          3735.1380
# 1               Tier 3  Supermarket Type2           443.4228
# 2               Tier 1  Supermarket Type1          2097.2700

# %%
# shape
df.shape
# Out:
# (8523, 12)

# %%
# df.info()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8523 entries, 0 to 8522
# Data columns (total 12 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Item_Identifier            8523 non-null   object
#  1   Item_Weight                7060 non-null   float64
#  2   Item_Fat_Content           8523 non-null   object
#  3   Item_Visibility            8523 non-null   float64
#  4   Item_Type                  8523 non-null   object
#  5   Item_MRP                   8523 non-null   float64
#  6   Outlet_Identifier          8523 non-null   object
#  7   Outlet_Establishment_Year  8523 non-null   int64
#  8   Outlet_Size                6113 non-null   object
#  9   Outlet_Location_Type       8523 non-null   object
#  10  Outlet_Type                8523 non-null   object
#  11  Item_Outlet_Sales          8523 non-null   float64
# dtypes: float64(4), int64(1), object(7)
# memory usage: 799.2+ KB

# %%
# unique values check : nunique()
df.select_dtypes(include = 'object').nunique()
# Out:
# Item_Identifier         1559
# Item_Fat_Content           5
# Item_Type                 16
# Outlet_Identifier         10
# Outlet_Size                3
# Outlet_Location_Type       3
# Outlet_Type                4
# dtype: int64

# %%
# get the count of null in df
df.isna().sum()
# Out:
# Item_Identifier                 0
# Item_Weight                  1463
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                  2410
# Outlet_Location_Type            0
# Outlet_Type                     0
# Item_Outlet_Sales               0
# dtype: int64

# %%
len(df)
# Out:
# 8523

# %%
import numpy as np
# convert that into percentages upto 2 decimal places
np.round(100 * df.isna().sum()/len(df), 2)
# Out:
# Item_Identifier               0.00
# Item_Weight                  17.17
# Item_Fat_Content              0.00
# Item_Visibility               0.00
# Item_Type                     0.00
# Item_MRP                      0.00
# Outlet_Identifier             0.00
# Outlet_Establishment_Year     0.00
# Outlet_Size                  28.28
# Outlet_Location_Type          0.00
# Outlet_Type                   0.00
# Item_Outlet_Sales             0.00
# dtype: float64

# %%
# drop the null values
df = df.dropna()
df.shape
# Out:
# (4650, 12)

# %%
# reset index after dropping
# view the top results
df.reset_index(inplace = True, drop = True)

# %%
df.head(2)
# Out:
#    index Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0      0           FDA15         9.30          Low Fat         0.016047
# 1      1           DRC01         5.92          Regular         0.019278
#
#      Item_Type  Item_MRP Outlet_Identifier  Outlet_Establishment_Year  \
# 0        Dairy  249.8092            OUT049                       1999
# 1  Soft Drinks   48.2692            OUT018                       2009
#
#   Outlet_Size Outlet_Location_Type        Outlet_Type  Item_Outlet_Sales
# 0      Medium               Tier 1  Supermarket Type1          3735.1380
# 1      Medium               Tier 3  Supermarket Type2           443.4228

# %%
# What all different item_type / categories are there in the dataset ?
df.Item_Type.unique()
# Out:
# array(['Dairy', 'Soft Drinks', 'Meat', 'Household', 'Baking Goods',
#        'Snack Foods', 'Fruits and Vegetables', 'Breakfast',
#        'Health and Hygiene', 'Frozen Foods', 'Hard Drinks', 'Canned',
#        'Starchy Foods', 'Breads', 'Others', 'Seafood'], dtype=object)

# %%
# count of unique item_type
len(df.Item_Type.unique())
# Out:
# 16

# %%
# value_counts()
df.Item_Type.value_counts()
# Out:
# Item_Type
# Fruits and Vegetables    670
# Snack Foods              656
# Household                498
# Frozen Foods             477
# Dairy                    380
# Canned                   361
# Baking Goods             351
# Health and Hygiene       277
# Soft Drinks              241
# Meat                     221
# Breads                   132
# Hard Drinks              117
# Others                    91
# Starchy Foods             87
# Breakfast                 58
# Seafood                   33
# Name: count, dtype: int64

# %%
df.head(3)
# Out:
#    index Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0      0           FDA15         9.30          Low Fat         0.016047
# 1      1           DRC01         5.92          Regular         0.019278
# 2      2           FDN15        17.50          Low Fat         0.016760
#
#      Item_Type  Item_MRP Outlet_Identifier  Outlet_Establishment_Year  \
# 0        Dairy  249.8092            OUT049                       1999
# 1  Soft Drinks   48.2692            OUT018                       2009
# 2         Meat  141.6180            OUT049                       1999
#
#   Outlet_Size Outlet_Location_Type        Outlet_Type  Item_Outlet_Sales
# 0      Medium               Tier 1  Supermarket Type1          3735.1380
# 1      Medium               Tier 3  Supermarket Type2           443.4228
# 2      Medium               Tier 1  Supermarket Type1          2097.2700

# %%
df.drop(columns = 'index', inplace = True)

# %%
# Total count of Items
df.Item_Identifier.nunique()
# Out:
# 1535

# %% [markdown]
# ### Add a new column

# %%
df.select_dtypes(include = ['int64', 'float64']).head(2)
# Out:
#    Item_Weight  Item_Visibility  Item_MRP  Outlet_Establishment_Year  \
# 0         9.30         0.016047  249.8092                       1999
# 1         5.92         0.019278   48.2692                       2009
#
#    Item_Outlet_Sales
# 0          3735.1380
# 1           443.4228

# %%
# calculate quantity sold
df['quantity'] = round(df['Item_Outlet_Sales'] / df['Item_MRP'],0)
df.head(3)
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility    Item_Type  \
# 0           FDA15         9.30          Low Fat         0.016047        Dairy
# 1           DRC01         5.92          Regular         0.019278  Soft Drinks
# 2           FDN15        17.50          Low Fat         0.016760         Meat
#
#    Item_MRP Outlet_Identifier  Outlet_Establishment_Year Outlet_Size  \
# 0  249.8092            OUT049                       1999      Medium
# 1   48.2692            OUT018                       2009      Medium
# 2  141.6180            OUT049                       1999      Medium
#
#   Outlet_Location_Type        Outlet_Type  Item_Outlet_Sales  quantity
# 0               Tier 1  Supermarket Type1          3735.1380      15.0
# 1               Tier 3  Supermarket Type2           443.4228       9.0
# 2               Tier 1  Supermarket Type1          2097.2700      15.0

# %%
# Top 5 most selling Item_Type in terms of quantity

d = df.groupby("Item_Type").quantity.sum().reset_index().sort_values(by = 'quantity', ascending = False).reset_index(drop = True)
d.head()
# Out:
#                Item_Type  quantity
# 0            Snack Foods   10697.0
# 1  Fruits and Vegetables   10598.0
# 2              Household    8011.0
# 3           Frozen Foods    7416.0
# 4                  Dairy    5823.0

# %%
# Avg mrp for each item_type
# SELECT Item_Type, avg(Item_MRP)
#     from df
#     group by Item_Type

df.groupby('Item_Type').Item_MRP.mean()
# Out:
# Item_Type
# Baking Goods             125.795653
# Breads                   141.300639
# Breakfast                134.090683
# Canned                   138.551179
# Dairy                    149.481471
# Frozen Foods             140.095830
# Fruits and Vegetables    145.418257
# Hard Drinks              140.102908
# Health and Hygiene       131.437324
# Household                149.884244
# Meat                     140.279344
# Others                   137.640870
# Seafood                  146.595782
# Snack Foods              147.569955
# Soft Drinks              130.910182
# Starchy Foods            151.256747
# Name: Item_MRP, dtype: float64

# %%
df.groupby('Item_Type').Item_MRP.mean().reset_index().sort_values(by = 'Item_MRP', ascending = False).head(5)
# Out:
#         Item_Type    Item_MRP
# 15  Starchy Foods  151.256747
# 9       Household  149.884244
# 4           Dairy  149.481471
# 13    Snack Foods  147.569955
# 12        Seafood  146.595782

# %%
# Top 5 most selling products in terms of revenue
df.groupby('Item_Type').Item_Outlet_Sales.sum().reset_index().sort_values(by = 'Item_Outlet_Sales', ascending = False)
# Out:
#                 Item_Type  Item_Outlet_Sales
# 13            Snack Foods       1.568592e+06
# 6   Fruits and Vegetables       1.549511e+06
# 9               Household       1.188504e+06
# 5            Frozen Foods       1.059900e+06
# 4                   Dairy       8.882198e+05
# 3                  Canned       7.960811e+05
# 0            Baking Goods       7.184262e+05
# 8      Health and Hygiene       5.922457e+05
# 10                   Meat       4.972714e+05
# 14            Soft Drinks       4.941315e+05
# 1                  Breads       3.154407e+05
# 7             Hard Drinks       2.612932e+05
# 15          Starchy Foods       2.160887e+05
# 11                 Others       1.996714e+05
# 2               Breakfast       1.277837e+05
# 12                Seafood       9.181382e+04

# %%
df.head(2)
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility    Item_Type  \
# 0           FDA15         9.30          Low Fat         0.016047        Dairy
# 1           DRC01         5.92          Regular         0.019278  Soft Drinks
#
#    Item_MRP Outlet_Identifier  Outlet_Establishment_Year Outlet_Size  \
# 0  249.8092            OUT049                       1999      Medium
# 1   48.2692            OUT018                       2009      Medium
#
#   Outlet_Location_Type        Outlet_Type  Item_Outlet_Sales  quantity
# 0               Tier 1  Supermarket Type1          3735.1380      15.0
# 1               Tier 3  Supermarket Type2           443.4228       9.0

# %%
#find avg mrp & total sales for every Item_Type X Outlet_Size
# select Item_Type, Outlet_Size  ,  avg(Item_MRP) as avg_mrp,  sum(Item_MRP) as avg_mrp,  sum(Item_Outlet_Sales)
# from table
# group by Item_Type, Outlet_Size

df.groupby(['Item_Type', 'Outlet_Size']).agg({'Item_MRP':'mean',
                                              'Item_Outlet_Sales':'sum'}).reset_index().rename(columns = {"Item_MRP":'avg_mrp',
                                                                                                          "Item_Outlet_Sales":"Total_Sales"})
# Out:
#                 Item_Type Outlet_Size     avg_mrp  Total_Sales
# 0            Baking Goods        High  129.202044  149715.7828
# 1            Baking Goods      Medium  124.823967  260328.4658
# 2            Baking Goods       Small  124.973010  308381.9150
# 3                  Breads        High  133.758960   52018.2882
# 4                  Breads      Medium  137.990438  115095.5144
# 5                  Breads       Small  147.858320  148326.9240
# 6               Breakfast        High  147.490585   27355.7246
# 7               Breakfast      Medium  129.017096   52710.7202
# 8               Breakfast       Small  131.722730   47717.2202
# 9                  Canned        High  135.442708  143732.2382
# 10                 Canned      Medium  136.883055  283819.8872
# 11                 Canned       Small  141.491103  368528.9554
# 12                  Dairy        High  153.509173  196254.5370
# 13                  Dairy      Medium  148.722985  331811.4170
# 14                  Dairy       Small  148.087613  360153.8572
# 15           Frozen Foods        High  136.829250  203696.8494
# 16           Frozen Foods      Medium  142.196088  399478.6684
# 17           Frozen Foods       Small  139.655719  456724.1524
# 18  Fruits and Vegetables        High  145.572870  341526.7706
# 19  Fruits and Vegetables      Medium  141.926119  598585.4926
# 20  Fruits and Vegetables       Small  149.070800  609398.7504
# 21            Hard Drinks        High  141.927522   54362.5700
# 22            Hard Drinks      Medium  142.510904  112373.0582
# 23            Hard Drinks       Small  136.122386   94557.5818
# 24     Health and Hygiene        High  135.110980  119135.5888
# 25     Health and Hygiene      Medium  129.165200  221690.0944
# 26     Health and Hygiene       Small  131.681104  251420.0618
# 27              Household        High  147.097522  248046.4532
# 28              Household      Medium  148.327454  451084.8264
# 29              Household       Small  152.727281  489372.9870
# 30                   Meat        High  137.244790   95200.0788
# 31                   Meat      Medium  134.336873  199805.2484
# 32                   Meat       Small  148.061717  202266.0452
# 33                 Others        High  132.576613   35238.1308
# 34                 Others      Medium  136.372854   84844.8914
# 35                 Others       Small  141.007837   79588.4004
# 36                Seafood        High  134.864240    8146.7288
# 37                Seafood      Medium  149.272286   33993.7506
# 38                Seafood       Small  148.109114   49673.3406
# 39            Snack Foods        High  145.847086  309246.1234
# 40            Snack Foods      Medium  150.904812  628958.6228
# 41            Snack Foods       Small  144.922309  630387.4296
# 42            Soft Drinks        High  131.758473  115234.6666
# 43            Soft Drinks      Medium  130.693859  186081.1130
# 44            Soft Drinks       Small  130.693536  192815.6800
# 45          Starchy Foods        High  158.157074   43753.0470
# 46          Starchy Foods      Medium  150.618788   75130.8694
# 47          Starchy Foods       Small  148.038641   97204.8026

# %%
df.groupby(['Item_Type', 'Outlet_Size']).agg({'Item_MRP':'mean',
                                              'Item_Outlet_Sales':['mean','sum', 'count'],
                                              }).reset_index()
# Out:
#                 Item_Type Outlet_Size    Item_MRP Item_Outlet_Sales  \
#                                              mean              mean
# 0            Baking Goods        High  129.202044       2050.901134
# 1            Baking Goods      Medium  124.823967       1942.749745
# 2            Baking Goods       Small  124.973010       2141.541076
# 3                  Breads        High  133.758960       2080.731528
# 4                  Breads      Medium  137.990438       2213.375277
# 5                  Breads       Small  147.858320       2696.853164
# 6               Breakfast        High  147.490585       2104.286508
# 7               Breakfast      Medium  129.017096       2108.428808
# 8               Breakfast       Small  131.722730       2385.861010
# 9                  Canned        High  135.442708       2211.265203
# 10                 Canned      Medium  136.883055       1957.378532
# 11                 Canned       Small  141.491103       2440.589109
# 12                  Dairy        High  153.509173       2453.181713
# 13                  Dairy      Medium  148.722985       2197.426603
# 14                  Dairy       Small  148.087613       2417.139981
# 15           Frozen Foods        High  136.829250       2214.096189
# 16           Frozen Foods      Medium  142.196088       2159.344154
# 17           Frozen Foods       Small  139.655719       2283.620762
# 18  Fruits and Vegetables        High  145.572870       2405.118103
# 19  Fruits and Vegetables      Medium  141.926119       2192.620852
# 20  Fruits and Vegetables       Small  149.070800       2389.799021
# 21            Hard Drinks        High  141.927522       2363.590000
# 22            Hard Drinks      Medium  142.510904       2161.020350
# 23            Hard Drinks       Small  136.122386       2251.370995
# 24     Health and Hygiene        High  135.110980       1953.042439
# 25     Health and Hygiene      Medium  129.165200       2015.364495
# 26     Health and Hygiene       Small  131.681104       2371.887375
# 27              Household        High  147.097522       2408.217992
# 28              Household      Medium  148.327454       2374.130665
# 29              Household       Small  152.727281       2387.185302
# 30                   Meat        High  137.244790       2321.953141
# 31                   Meat      Medium  134.336873       2148.443531
# 32                   Meat       Small  148.061717       2324.897071
# 33                 Others        High  132.576613       2202.383175
# 34                 Others      Medium  136.372854       2293.105173
# 35                 Others       Small  141.007837       2094.431589
# 36                Seafood        High  134.864240       1629.345760
# 37                Seafood      Medium  149.272286       2428.125043
# 38                Seafood       Small  148.109114       3548.095757
# 39            Snack Foods        High  145.847086       2473.968987
# 40            Snack Foods      Medium  150.904812       2320.880527
# 41            Snack Foods       Small  144.922309       2424.567037
# 42            Soft Drinks        High  131.758473       2351.727890
# 43            Soft Drinks      Medium  130.693859       2022.620793
# 44            Soft Drinks       Small  130.693536       1928.156800
# 45          Starchy Foods        High  158.157074       2302.791947
# 46          Starchy Foods      Medium  150.618788       2209.731453
# 47          Starchy Foods       Small  148.038641       2858.964782
#
#
#             sum count
# 0   149715.7828    73
# 1   260328.4658   134
# 2   308381.9150   144
# 3    52018.2882    25
# 4   115095.5144    52
# 5   148326.9240    55
# 6    27355.7246    13
# 7    52710.7202    25
# 8    47717.2202    20
# 9   143732.2382    65
# 10  283819.8872   145
# 11  368528.9554   151
# 12  196254.5370    80
# 13  331811.4170   151
# 14  360153.8572   149
# 15  203696.8494    92
# 16  399478.6684   185
# 17  456724.1524   200
# 18  341526.7706   142
# 19  598585.4926   273
# 20  609398.7504   255
# 21   54362.5700    23
# 22  112373.0582    52
# 23   94557.5818    42
# 24  119135.5888    61
# 25  221690.0944   110
# 26  251420.0618   106
# 27  248046.4532   103
# 28  451084.8264   190
# 29  489372.9870   205
# 30   95200.0788    41
# 31  199805.2484    93
# 32  202266.0452    87
# 33   35238.1308    16
# 34   84844.8914    37
# 35   79588.4004    38
# 36    8146.7288     5
# 37   33993.7506    14
# 38   49673.3406    14
# 39  309246.1234   125
# 40  628958.6228   271
# 41  630387.4296   260
# 42  115234.6666    49
# 43  186081.1130    92
# 44  192815.6800   100
# 45   43753.0470    19
# 46   75130.8694    34
# 47   97204.8026    34

# %%
# Filter the products having Item_MRP > 200

# df[filter condn]
condn = df['Item_MRP'] > 200

df_200 = df[condn]
df_200.shape
# Out:
# (811, 13)

# %%
# Filter the Dairy products having Item_MRP > 200
condn = (df['Item_Type'] == "Dairy")  & (df['Item_MRP']>200)

dairy_df_200 = df[condn]
dairy_df_200
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility Item_Type  \
# 0              FDA15        9.300          Low Fat         0.016047     Dairy
# 14             FDU02       13.350          Low Fat         0.102492     Dairy
# 25             FDU02       13.350          Low Fat         0.102512     Dairy
# 63             FDD03       13.300          Low Fat         0.079806     Dairy
# 111            DRC27       13.800          Low Fat         0.058091     Dairy
# ...              ...          ...              ...              ...       ...
# 4368           FDY14       10.300          Low Fat         0.070040     Dairy
# 4410           FDC04       15.600          Low Fat         0.045056     Dairy
# 4468           FDF40       20.250          Regular         0.022508     Dairy
# 4517           FDB03       17.750          Regular         0.157471     Dairy
# 4595           FDC39        7.405          Low Fat         0.159165     Dairy
#
#       Item_MRP Outlet_Identifier  Outlet_Establishment_Year Outlet_Size  \
# 0     249.8092            OUT049                       1999      Medium
# 14    230.5352            OUT035                       2004       Small
# 25    230.6352            OUT046                       1997       Small
# 63    232.5300            OUT046                       1997       Small
# 111   245.1802            OUT035                       2004       Small
# ...        ...               ...                        ...         ...
# 4368  263.0226            OUT046                       1997       Small
# 4410  242.3854            OUT049                       1999      Medium
# 4468  248.1092            OUT035                       2004       Small
# 4517  239.1538            OUT018                       2009      Medium
# 4595  207.1296            OUT035                       2004       Small
#
#      Outlet_Location_Type        Outlet_Type  Item_Outlet_Sales  quantity
# 0                  Tier 1  Supermarket Type1          3735.1380      15.0
# 14                 Tier 2  Supermarket Type1          2748.4224      12.0
# 25                 Tier 1  Supermarket Type1          3435.5280      15.0
# 63                 Tier 1  Supermarket Type1           699.0900       3.0
# 111                Tier 2  Supermarket Type1          5650.6446      23.0
# ...                   ...                ...                ...       ...
# 4368               Tier 1  Supermarket Type1          4229.1616      16.0
# 4410               Tier 1  Supermarket Type1          2416.8540      10.0
# 4468               Tier 2  Supermarket Type1          4731.1748      19.0
# 4517               Tier 3  Supermarket Type2          4326.3684      18.0
# 4595               Tier 2  Supermarket Type1          3739.1328      18.0
#
# [106 rows x 13 columns]

# %% [markdown]
# ### Apply function
#
# - Apply function can be used to perform pre-processing/data-manipulation on your data both row wise and column wise.
# - It is a faster method than simply using a **for** loop over your dataframe.
# - Almost every time I need to iterate over a dataframe or it's rows/columns, I will think of using the `apply`.
# - Hence, it is widely used in feature engineering code.

# %% [markdown]
# - You can also use `apply` to implement a **condition** individually on every row/column of your dataframe.
# - Suppose you want to clip Item_MRP to 200 and not consider any value greater than that.
# ```python
# def clip_price(price):
#     if price > 200:
#         price = 200
#     return price
# ```

# %% [markdown]
# ### clip the item mrp to Rs 200.

# %%
df.head(1)
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility Item_Type  \
# 0           FDA15          9.3          Low Fat         0.016047     Dairy
#
#    Item_MRP Outlet_Identifier  Outlet_Establishment_Year Outlet_Size  \
# 0  249.8092            OUT049                       1999      Medium
#
#   Outlet_Location_Type        Outlet_Type  Item_Outlet_Sales  quantity
# 0               Tier 1  Supermarket Type1           3735.138      15.0

# %%
# Using for loop
df['Item_MRP_clipped'] = df['Item_MRP']

for i in range(len(df)):
  if df['Item_MRP_clipped'][i] > 200:
    df['Item_MRP_clipped'][i] = 200
# Out:
# <ipython-input-49-42ddf72236ad>:6: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['Item_MRP_clipped'][i] = 200
# <ipython-input-49-42ddf72236ad>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Item_MRP_clipped'][i] = 200
# <ipython-input-49-42ddf72236ad>:6: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['Item_MRP_clipped'][i] = 200
# <ipython-input-49-42ddf72236ad>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Item_MRP_clipped'][i] = 200
# <ipython-input-49-42ddf72236ad>:6: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['Item_MRP_clipped'][i] = 200
# <ipython-input-49-42ddf72236ad>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Item_MRP_clipped'][i] = 200
# <ipython-input-49-42ddf72236ad>:6: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['Item_MRP_clipped'][i] = 200
# <ipython-input-49-42ddf72236ad>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Item_MRP_clipped'][i] = 200
# <ipython-input-49-42ddf72236ad>:6: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['Item_MRP_clipped'][i] = 200
# <ipython-input-49-42ddf72236ad>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Item_MRP_clipped'][i] = 200
# <ipython-input-49-42ddf72236ad>:6: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['Item_MRP_clipped'][i] = 200
# <ipython-input-49-42ddf72236ad>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Item_MRP_clipped'][i] = 200
# <ipython-input-49-42ddf72236ad>:6: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['Item_MRP_clipped'][i] = 200
# <ipython-input-49-42ddf72236ad>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Item_MRP_clipped'][i] = 200
# <ipython-input-49-42ddf72236ad>:6: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['Item_MRP_clipped'][i] = 200
# <ipython-input-49-42ddf72236ad>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Item_MRP_clipped'][i] = 200
# <ipython-input-49-42ddf72236ad>:6: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['Item_MRP_clipped'][i] = 200
# <ipython-input-49-42ddf72236ad>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Item_MRP_clipped'][i] = 200
# <ipython-input-49-42ddf72236ad>:6: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['Item_MRP_clipped'][i] = 200
# <ipython-input-49-42ddf72236ad>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Item_MRP_clipped'][i] = 200
# <ipython-input-49-42ddf72236ad>:6: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['Item_MRP_clipped'][i] = 200
# <ipython-input-49-42ddf72236ad>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Item_MRP_clipped'][i] = 200
# <ipython-input-49-42ddf72236ad>:6: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['Item_MRP_clipped'][i] = 200
# <ipython-input-49-42ddf72236ad>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Item_MRP_clipped'][i] = 200
# <ipython-input-49-42ddf72236ad>:6: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['Item_MRP_clipped'][i] = 200
# <ipython-input-49-42ddf72236ad>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Item_MRP_clipped'][i] = 200
# <ipython-input-49-42ddf72236ad>:6: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['Item_MRP_clipped'][i] = 200
# <ipython-input-49-42ddf72236ad>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Item_MRP_clipped'][i] = 200
# <ipython-input-49-42ddf72236ad>:6: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['Item_MRP_clipped'][i] = 200
# <ipython-input-49-42ddf72236ad>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Item_MRP_clipped'][i] = 200
# <ipython-input-49-42ddf72236ad>:6: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['Item_MRP_clipped'][i] = 200
# <ipython-input-49-42ddf72236ad>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Item_MRP_clipped'][i] = 200
# <ipython-input-49-42ddf72236ad>:6: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['Item_MRP_clipped'][i] = 200
# <ipython-input-49-42ddf72236ad>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Item_MRP_clipped'][i] = 200
# <ipython-input-49-42ddf72236ad>:6: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['Item_MRP_clipped'][i] = 200
# <ipython-input-49-42ddf72236ad>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Item_MRP_clipped'][i] = 200
# <ipython-input-49-42ddf72236ad>:6: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['Item_MRP_clipped'][i] = 200
# <ipython-input-49-42ddf72236ad>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Item_MRP_clipped'][i] = 200
# <ipython-input-49-42ddf72236ad>:6: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['Item_MRP_clipped'][i] = 200
# <ipython-input-49-42ddf72236ad>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Item_MRP_clipped'][i] = 200
# <ipython-input-49-42ddf72236ad>:6: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['Item_MRP_clipped'][i] = 200
# <ipython-input-49-42ddf72236ad>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Item_MRP_clipped'][i] = 200
# <ipython-input-49-42ddf72236ad>:6: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['Item_MRP_clipped'][i] = 200
# <ipython-input-49-42ddf72236ad>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Item_MRP_clipped'][i] = 200
# <ipython-input-49-42ddf72236ad>:6: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['Item_MRP_clipped'][i] = 200
# <ipython-input-49-42ddf72236ad>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Item_MRP_clipped'][i] = 200
# <ipython-input-49-42ddf72236ad>:6: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['Item_MRP_clipped'][i] = 200
# <ipython-input-49-42ddf72236ad>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Item_MRP_clipped'][i] = 200
# <ipython-input-49-42ddf72236ad>:6: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['Item_MRP_clipped'][i] = 200
# <ipython-input-49-42ddf72236ad>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Item_MRP_clipped'][i] = 200
# <ipython-input-49-42ddf72236ad>:6: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['Item_MRP_clipped'][i] = 200
# <ipython-input-49-42ddf72236ad>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Item_MRP_clipped'][i] = 200
# <ipython-input-49-42ddf72236ad>:6: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['Item_MRP_clipped'][i] = 200
# <ipython-input-49-42ddf72236ad>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Item_MRP_clipped'][i] = 200
# <ipython-input-49-42ddf72236ad>:6: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['Item_MRP_clipped'][i] = 200
# <ipython-input-49-42ddf72236ad>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Item_MRP_clipped'][i] = 200
# <ipython-input-49-42ddf72236ad>:6: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['Item_MRP_clipped'][i] = 200
# <ipython-input-49-42ddf72236ad>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Item_MRP_clipped'][i] = 200
# <ipython-input-49-42ddf72236ad>:6: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['Item_MRP_clipped'][i] = 200
# <ipython-input-49-42ddf72236ad>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Item_MRP_clipped'][i] = 200
# <ipython-input-49-42ddf72236ad>:6: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['Item_MRP_clipped'][i] = 200
# <ipython-input-49-42ddf72236ad>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Item_MRP_clipped'][i] = 200
# <ipython-input-49-42ddf72236ad>:6: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['Item_MRP_clipped'][i] = 200
# <ipython-input-49-42ddf72236ad>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Item_MRP_clipped'][i] = 200
# <ipython-input-49-42ddf72236ad>:6: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['Item_MRP_clipped'][i] = 200
# <ipython-input-49-42ddf72236ad>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Item_MRP_clipped'][i] = 200
# <ipython-input-49-42ddf72236ad>:6: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['Item_MRP_clipped'][i] = 200
# <ipython-input-49-42ddf72236ad>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Item_MRP_clipped'][i] = 200
# <ipython-input-49-42ddf72236ad>:6: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['Item_MRP_clipped'][i] = 200
# <ipython-input-49-42ddf72236ad>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Item_MRP_clipped'][i] = 200
# <ipython-input-49-42ddf72236ad>:6: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['Item_MRP_clipped'][i] = 200
# <ipython-input-49-42ddf72236ad>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Item_MRP_clipped'][i] = 200
# <ipython-input-49-42ddf72236ad>:6: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['Item_MRP_clipped'][i] = 200
# <ipython-input-49-42ddf72236ad>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Item_MRP_clipped'][i] = 200
# <ipython-input-49-42ddf72236ad>:6: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['Item_MRP_clipped'][i] = 200
# <ipython-input-49-42ddf72236ad>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Item_MRP_clipped'][i] = 200
# <ipython-input-49-42ddf72236ad>:6: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['Item_MRP_clipped'][i] = 200
# <ipython-input-49-42ddf72236ad>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Item_MRP_clipped'][i] = 200
# <ipython-input-49-42ddf72236ad>:6: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['Item_MRP_clipped'][i] = 200
# <ipython-input-49-42ddf72236ad>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Item_MRP_clipped'][i] = 200
# <ipython-input-49-42ddf72236ad>:6: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['Item_MRP_clipped'][i] = 200
# <ipython-input-49-42ddf72236ad>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['Item_MRP_clipped'][i] = 200
# <ipython-input-49-42ddf72236ad>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Item_MRP_clipped'][i] = 200
# <ipython-input-49-42ddf72236ad>:6: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['Item_MRP_clipped'][i] = 200
# <ipython-input-49-42ddf72236ad>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Item_MRP_clipped'][i] = 200
# <ipython-input-49-42ddf72236ad>:6: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['Item_MRP_clipped'][i] = 200
# <ipython-input-49-42ddf72236ad>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Item_MRP_clipped'][i] = 200
# <ipython-input-49-42ddf72236ad>:6: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['Item_MRP_clipped'][i] = 200
# <ipython-input-49-42ddf72236ad>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Item_MRP_clipped'][i] = 200
# <ipython-input-49-42ddf72236ad>:6: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['Item_MRP_clipped'][i] = 200
# <ipython-input-49-42ddf72236ad>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Item_MRP_clipped'][i] = 200
# <ipython-input-49-42ddf72236ad>:6: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['Item_MRP_clipped'][i] = 200
# <ipython-input-49-42ddf72236ad>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Item_MRP_clipped'][i] = 200
# <ipython-input-49-42ddf72236ad>:6: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['Item_MRP_clipped'][i] = 200
# <ipython-input-49-42ddf72236ad>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Item_MRP_clipped'][i] = 200
# <ipython-input-49-42ddf72236ad>:6: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['Item_MRP_clipped'][i] = 200
# <ipython-input-49-42ddf72236ad>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Item_MRP_clipped'][i] = 200
# <ipython-input-49-42ddf72236ad>:6: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['Item_MRP_clipped'][i] = 200
# <ipython-input-49-42ddf72236ad>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Item_MRP_clipped'][i] = 200
# <ipython-input-49-42ddf72236ad>:6: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['Item_MRP_clipped'][i] = 200
# <ipython-input-49-42ddf72236ad>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Item_MRP_clipped'][i] = 200
# <ipython-input-49-42ddf72236ad>:6: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['Item_MRP_clipped'][i] = 200
# <ipython-input-49-42ddf72236ad>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Item_MRP_clipped'][i] = 200
# <ipython-input-49-42ddf72236ad>:6: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['Item_MRP_clipped'][i] = 200
# <ipython-input-49-42ddf72236ad>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Item_MRP_clipped'][i] = 200
# <ipython-input-49-42ddf72236ad>:6: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['Item_MRP_clipped'][i] = 200
# <ipython-input-49-42ddf72236ad>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Item_MRP_clipped'][i] = 200
# <ipython-input-49-42ddf72236ad>:6: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['Item_MRP_clipped'][i] = 200
# <ipython-input-49-42ddf72236ad>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Item_MRP_clipped'][i] = 200

# %%
df['Item_MRP_clipped'].describe()
# Out:
# count    4650.000000
# mean      135.193818
# std        52.862429
# min        31.490000
# 25%        94.409400
# 50%       142.979900
# 75%       186.614150
# max       200.000000
# Name: Item_MRP_clipped, dtype: float64

# %%
def clip_price(price):
  if price > 200:
    return 200
  else:
    return price

clip_price(249)
# Out:
# 200

# %%
# using apply method
df["Item_MRP_using_apply"] = df['Item_MRP'].apply(clip_price)

# %%
df['Item_MRP_using_apply'].max()
# Out:
# 200.0

# %%
# Using lambda
df['clipped_price2'] = df['Item_MRP'].apply(lambda x: x if x <200 else 200 )

# %%
df['clipped_price2'].max()
# Out:
# 200.0

# %%
len('Dairy')
# Out:
# 5

# %% [markdown]
# ### Add a new column Length_of_item_type

# %%
# define a function to do that task for one value
df['Length_of_item_type'] = df['Item_Type'].apply(lambda x: len(x))
df.head(3)
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility    Item_Type  \
# 0           FDA15         9.30          Low Fat         0.016047        Dairy
# 1           DRC01         5.92          Regular         0.019278  Soft Drinks
# 2           FDN15        17.50          Low Fat         0.016760         Meat
#
#    Item_MRP Outlet_Identifier  Outlet_Establishment_Year Outlet_Size  \
# 0  249.8092            OUT049                       1999      Medium
# 1   48.2692            OUT018                       2009      Medium
# 2  141.6180            OUT049                       1999      Medium
#
#   Outlet_Location_Type        Outlet_Type  Item_Outlet_Sales  quantity  \
# 0               Tier 1  Supermarket Type1          3735.1380      15.0
# 1               Tier 3  Supermarket Type2           443.4228       9.0
# 2               Tier 1  Supermarket Type1          2097.2700      15.0
#
#    Item_MRP_clipped_using_apply  clipped_price2  Length_of_item_type
# 0                      200.0000        200.0000                    5
# 1                       48.2692         48.2692                   11
# 2                      141.6180        141.6180                    4

# %%
# add a new col called item_type_length

# %%
def length_calculator(text):
  return len(text)

length_calculator("Dairy"), length_calculator("Soft Drinks")
# Out:
# (5, 11)

# %% [markdown]
# ### Encoding Outlet_Location_Type

# %% [markdown]
# - Suppose you want to label encode Outlet_Location_Type as 0, 1 and 2 for Tier 1, Tier 2 and Tier 3 city, your logic would be:
#
# ```python
# def label_encode(city):
#     if city == 'Tier 1':
#         label = 0
#     elif city == 'Tier 2':
#         label = 1
#     else:
#         label = 2
#     return label
# ```
# - You can use the `apply` to operate `label_encode` logic on every row of the Outlet_Location_Type column.

# %%
# display all the Outlet_Location_Type categories

# %%
def encode(Location_Type):
  if(Location_Type == 'Tier 1'):
    Location_Type = 1
  elif(Location_Type == 'Tier 2'):
    Location_Type = 2
  elif(Location_Type == 'Tier 3'):
    Location_Type = 3
  return Location_Type

# %%
df['Outlet_Location_Type'] = df['Outlet_Location_Type'].apply(encode)

# %%
# check whether the values are encoded or not
df['Outlet_Location_Type'].value_counts()
# Out:
# Outlet_Location_Type
# 3    3350
# 2    2785
# 1    2388
# Name: count, dtype: int64

# %% [markdown]
# Pandas library of python is very useful for the manipulation of mathematical data and is widely used in the field of machine learning.It comprises
# many methods for its proper functioning. loc() and iloc() are one of those methods. These are used in slicing data from the Pandas DataFrame.
#
# The loc() function is label based data selecting method which means that we have to pass the name of the row or column which we want to select. This method includes the last element of the range passed in it, unlike iloc(). loc() can accept the boolean data unlike iloc(). Many operations can be performed using the loc() method

# %% [markdown]
# ### **Subsetting df based on some conditions**

# %%
df.sample(5)
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 2764           FDH22        6.405          Low Fat         0.136513
# 117            FDW20       20.750          Low Fat         0.024129
# 364            FDK15       10.800          Low Fat         0.098567
# 1973           FDP37       15.600          Low Fat         0.142987
# 2540           FDZ23       17.750          Regular         0.067778
#
#                   Item_Type  Item_MRP Outlet_Identifier  \
# 2764            Snack Foods  128.7678            OUT049
# 117   Fruits and Vegetables  124.1730            OUT013
# 364                    Meat   98.3042            OUT049
# 1973              Breakfast  130.3994            OUT013
# 2540           Baking Goods  186.9240            OUT018
#
#       Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 2764                       1999      Medium               Tier 1
# 117                        1987        High               Tier 3
# 364                        1999      Medium               Tier 1
# 1973                       1987        High               Tier 3
# 2540                       2009      Medium               Tier 3
#
#             Outlet_Type  Item_Outlet_Sales  quantity
# 2764  Supermarket Type1          3052.0272      24.0
# 117   Supermarket Type1          2956.1520      24.0
# 364   Supermarket Type1          1488.0630      15.0
# 1973  Supermarket Type1          2826.9868      22.0
# 2540  Supermarket Type2          3169.2080      17.0

# %%
# extract only records belonging to dairy category
# filter condition : df['Item_Type'] == "Dairy"
# df[filter condition]

df.Item_Type.unique()
# Out:
# array(['Dairy', 'Soft Drinks', 'Meat', 'Household', 'Baking Goods',
#        'Snack Foods', 'Fruits and Vegetables', 'Breakfast',
#        'Health and Hygiene', 'Frozen Foods', 'Hard Drinks', 'Canned',
#        'Starchy Foods', 'Breads', 'Others', 'Seafood'], dtype=object)

# %%
# select * from table
#   where Item_Type == "Dairy"

dairy_df = df[df['Item_Type'] == 'Dairy']
print(dairy_df.shape)

display(dairy_df.head(5))
# Out:
# (380, 16)
#    Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility Item_Type  \
# 0            FDA15        9.300          Low Fat         0.016047     Dairy
# 7            FDA03       18.500          Regular         0.045464     Dairy
# 14           FDU02       13.350          Low Fat         0.102492     Dairy
# 25           FDU02       13.350          Low Fat         0.102512     Dairy
# 51           DRG27        8.895          Low Fat         0.105274     Dairy
#
#     Item_MRP Outlet_Identifier  Outlet_Establishment_Year Outlet_Size  \
# 0   249.8092            OUT049                       1999      Medium
# 7   144.1102            OUT046                       1997       Small
# 14  230.5352            OUT035                       2004       Small
# 25  230.6352            OUT046                       1997       Small
# 51   39.9138            OUT049                       1999      Medium
#
#    Outlet_Location_Type        Outlet_Type  Item_Outlet_Sales  quantity  \
# 0                Tier 1  Supermarket Type1          3735.1380      15.0
# 7                Tier 1  Supermarket Type1          2187.1530      15.0
# 14               Tier 2  Supermarket Type1          2748.4224      12.0
# 25               Tier 1  Supermarket Type1          3435.5280      15.0
# 51               Tier 1  Supermarket Type1           690.4346      17.0
#
#     Item_MRP_clipped_using_apply  clipped_price2  Length_of_item_type
# 0                       200.0000        200.0000                    5
# 7                       144.1102        144.1102                    5
# 14                      200.0000        200.0000                    5
# 25                      200.0000        200.0000                    5
# 51                       39.9138         39.9138                    5

# %%
# select * from table
#   where Item_Type == "Dairy" and Item_MRP < 50

dairy_df_50 = df[(df['Item_Type'] == "Dairy" )  &  (df['Item_MRP'] < 50)]
dairy_df_50.shape
# Out:
# (32, 16)

# %%
# dairy_df_50?

# %%
# extract only records belonging to dairy category with MRP < 50
# c1 : df['Item_Type'] == 'Dairy'
# c2 : df['Item_MRP'] < 50
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility Item_Type  \
# 4001           FDT02       12.600          Low Fat         0.024195     Dairy
# 3584           FDE51        5.925          Regular         0.096387     Dairy
# 420            DRF03       19.100          Low Fat         0.045300     Dairy
# 1542           DRE03       19.600          Low Fat         0.024222     Dairy
# 4191           FDX38       10.500          Regular         0.048207     Dairy
#
#       Item_MRP Outlet_Identifier  Outlet_Establishment_Year Outlet_Size  \
# 4001   36.1874            OUT046                       1997       Small
# 3584   45.6086            OUT013                       1987        High
# 420    38.8138            OUT035                       2004       Small
# 1542   45.5718            OUT035                       2004       Small
# 4191   45.9376            OUT046                       1997       Small
#
#      Outlet_Location_Type        Outlet_Type  Item_Outlet_Sales  quantity  \
# 4001               Tier 1  Supermarket Type1           423.4488      12.0
# 3584               Tier 3  Supermarket Type1           356.8688       8.0
# 420                Tier 2  Supermarket Type1           365.5242       9.0
# 1542               Tier 2  Supermarket Type1           945.4360      21.0
# 4191               Tier 1  Supermarket Type1           575.2512      13.0
#
#       Item_MRP_copy1
# 4001        165.6526
# 3584        200.0000
# 420          98.0068
# 1542        178.0344
# 4191         55.1298

# %%
# all these 32 dairy products having price < 50 , visualize on price in ascending order
dairy_df_50.shape
# Out:
# (32, 14)

# %% [markdown]
# ### Merging dataframes
#
# - Joining and merging DataFrames is the core process to start with data analysis and machine learning tasks.
# - It is one of the toolkits which every Data Analyst or Data Scientist should master because in almost all the cases data comes from multiple source and files.
# - Pandas has two useful functions for merging dataframes:
#     - **concat()**
#     - **merge()**
#
# #### Creating dummy data

# %%
# union is stacking the rows one by one, join is joining the table using common column

# %%
# union & joins

# select * from table1   # 5 cols
# union
# select * from table2    # 4 cols

# Is union possible ? No

# %%
import pandas as pd
# create dummy data
df1 = pd.DataFrame({'A': ['A0', 'A1', 'A2', 'A3'],
                     'B': ['B0', 'B1', 'B2', 'B3'],
                     'C': ['C0', 'C1', 'C2', 'C3'],
                     'D': ['D0', 'D1', 'D2', 'D3']},
                    index=[0, 1, 2, 3])


df2 = pd.DataFrame({'A': ['A4', 'A5', 'A6', 'A7'],
                     'B': ['B4', 'B5', 'B6', 'B7'],
                     'C': ['C4', 'C5', 'C6', 'C7'],
                     'D': ['D4', 'D5', 'D6', 'D7']},
                    index=[4, 5, 6, 7])


df3 = pd.DataFrame({'A': ['A8', 'A9', 'A10', 'A11'],
                     'B': ['B8', 'B9', 'B10', 'B11'],
                     'C': ['C8', 'C9', 'C10', 'C11'],
                     'D': ['D8', 'D9', 'D10', 'D11']},
                    index=[8, 9, 10, 11])

# %% [markdown]
# ### a. concat() for combining dataframes
# - Suppose you have the following three dataframes: df1, df2 and df3 and you want to combine them **"row-wise"** so that they become a single dataframe like the given image:
# ![](https://i.imgur.com/LCnk88r.png)
# - You can use **concat()** here. You will have to pass the names of the DataFrames in a list as the argument to the concat().

# %%
# combine dataframes
pd.concat([df1,df2, df3])
# Out:
#       A    B    C    D
# 0    A0   B0   C0   D0
# 1    A1   B1   C1   D1
# 2    A2   B2   C2   D2
# 3    A3   B3   C3   D3
# 4    A4   B4   C4   D4
# 5    A5   B5   C5   D5
# 6    A6   B6   C6   D6
# 7    A7   B7   C7   D7
# 8    A8   B8   C8   D8
# 9    A9   B9   C9   D9
# 10  A10  B10  C10  D10
# 11  A11  B11  C11  D11

# %% [markdown]
# - pandas also provides you with an option to label the DataFrames, after the concatenation, with a key so that you may know which data came from which DataFrame.
# - You can achieve the same by passing additional argument **keys** specifying the label names of the DataFrames in a list.

# %%
# combine dataframes
result = pd.concat([df1, df2, df3], keys=['x', 'y', 'z'])
result
# Out:
#         A    B    C    D
# x 0    A0   B0   C0   D0
#   1    A1   B1   C1   D1
#   2    A2   B2   C2   D2
#   3    A3   B3   C3   D3
# y 4    A4   B4   C4   D4
#   5    A5   B5   C5   D5
#   6    A6   B6   C6   D6
#   7    A7   B7   C7   D7
# z 8    A8   B8   C8   D8
#   9    A9   B9   C9   D9
#   10  A10  B10  C10  D10
#   11  A11  B11  C11  D11

# %%
result.loc['y']
# Out:
#     A   B   C   D
# 4  A4  B4  C4  D4
# 5  A5  B5  C5  D5
# 6  A6  B6  C6  D6
# 7  A7  B7  C7  D7

# %% [markdown]
# - Mentioning the keys also makes it easy to retrieve data corresponding to a particular DataFrame.
# - You can retrieve the data of DataFrame df2 which had the label `y` by using the `loc` method.

# %%
# get second dataframe
result.loc['z']
# Out:
#       A    B    C    D
# 8    A8   B8   C8   D8
# 9    A9   B9   C9   D9
# 10  A10  B10  C10  D10
# 11  A11  B11  C11  D11

# %% [markdown]
# - When gluing together multiple DataFrames, you have a choice of how to handle the other axes (other than the one being concatenated). This can be done in the following three ways:
#
#     - Take the union of them all, `join='outer'`. This is the default option as it results in zero information loss.
#     - Take the intersection, `join='inner'`.
#     - Use a specific index, as passed to the `join_axes` argument.
#
# - Here is an example of each of these methods. First, the default `join='outer'` behavior:
# ![](https://i.imgur.com/VnwDMEG.png)

# %%
df1
# Out:
#     A   B   C   D
# 0  A0  B0  C0  D0
# 1  A1  B1  C1  D1
# 2  A2  B2  C2  D2
# 3  A3  B3  C3  D3

# %%
df4 = pd.DataFrame({'B': ['B2', 'B3', 'B6', 'B7'],
                        'D': ['D2', 'D3', 'D6', 'D7'],
                        'F': ['F2', 'F3', 'F6', 'F7']},
                       index=[2, 3, 6, 7])
df4
# Out:
#     B   D   F
# 2  B2  D2  F2
# 3  B3  D3  F3
# 6  B6  D6  F6
# 7  B7  D7  F7

# %%
pd.concat([df1, df4])
# Out:
#      A   B    C   D    F
# 0   A0  B0   C0  D0  NaN
# 1   A1  B1   C1  D1  NaN
# 2   A2  B2   C2  D2  NaN
# 3   A3  B3   C3  D3  NaN
# 2  NaN  B2  NaN  D2   F2
# 3  NaN  B3  NaN  D3   F3
# 6  NaN  B6  NaN  D6   F6
# 7  NaN  B7  NaN  D7   F7

# %%
# select col1, col2 from table1
# union
# select col1, col2, col3 from table2

# %%
# axis = 0 -> along the rows
pd.concat([df1,df4], axis = 0)
# Out:
#      A   B    C   D    F
# 0   A0  B0   C0  D0  NaN
# 1   A1  B1   C1  D1  NaN
# 2   A2  B2   C2  D2  NaN
# 3   A3  B3   C3  D3  NaN
# 2  NaN  B2  NaN  D2   F2
# 3  NaN  B3  NaN  D3   F3
# 6  NaN  B6  NaN  D6   F6
# 7  NaN  B7  NaN  D7   F7

# %%
df1
# Out:
#     A   B   C   D
# 0  A0  B0  C0  D0
# 1  A1  B1  C1  D1
# 2  A2  B2  C2  D2
# 3  A3  B3  C3  D3

# %%
df4
# Out:
#     B   D   F
# 2  B2  D2  F2
# 3  B3  D3  F3
# 6  B6  D6  F6
# 7  B7  D7  F7

# %%
pd.concat([df1,df4], axis = 1)
# Out:
#      A    B    C    D    B    D    F
# 0   A0   B0   C0   D0  NaN  NaN  NaN
# 1   A1   B1   C1   D1  NaN  NaN  NaN
# 2   A2   B2   C2   D2   B2   D2   F2
# 3   A3   B3   C3   D3   B3   D3   F3
# 6  NaN  NaN  NaN  NaN   B6   D6   F6
# 7  NaN  NaN  NaN  NaN   B7   D7   F7

# %%
result = pd.concat([df1, df4], axis=1, sort=False)
result
# Out:
#      A    B    C    D    B    D    F
# 0   A0   B0   C0   D0  NaN  NaN  NaN
# 1   A1   B1   C1   D1  NaN  NaN  NaN
# 2   A2   B2   C2   D2   B2   D2   F2
# 3   A3   B3   C3   D3   B3   D3   F3
# 6  NaN  NaN  NaN  NaN   B6   D6   F6
# 7  NaN  NaN  NaN  NaN   B7   D7   F7

# %% [markdown]
# - Here is the same thing with `join='inner'`:
# ![](https://i.imgur.com/ljcXuWl.png)

# %%
pd.concat([df1,df4], axis = 1, join = "outer")
# Out:
#      A    B    C    D    B    D    F
# 0   A0   B0   C0   D0  NaN  NaN  NaN
# 1   A1   B1   C1   D1  NaN  NaN  NaN
# 2   A2   B2   C2   D2   B2   D2   F2
# 3   A3   B3   C3   D3   B3   D3   F3
# 6  NaN  NaN  NaN  NaN   B6   D6   F6
# 7  NaN  NaN  NaN  NaN   B7   D7   F7

# %%
pd.concat([df1,df4], axis = 1, join = "inner")
# Out:
#     A   B   C   D   B   D   F
# 2  A2  B2  C2  D2  B2  D2  F2
# 3  A3  B3  C3  D3  B3  D3  F3

# %%
# pd.concat([df1,df4], axis = 1, join = "left")

# %%
result = pd.concat([df1, df4], axis=1)
result
# Out:
#      A    B    C    D    B    D    F
# 0   A0   B0   C0   D0  NaN  NaN  NaN
# 1   A1   B1   C1   D1  NaN  NaN  NaN
# 2   A2   B2   C2   D2   B2   D2   F2
# 3   A3   B3   C3   D3   B3   D3   F3
# 6  NaN  NaN  NaN  NaN   B6   D6   F6
# 7  NaN  NaN  NaN  NaN   B7   D7   F7

# %% [markdown]
# - Lastly, suppose we just wanted to `reuse the exact index` from the original DataFrame:
# ![](https://i.imgur.com/acMux4A.png)

# %%
result = pd.concat([df1, df4], axis=1).reindex(df4.index)
result
# Out:
#      A    B    C    D   B   D   F
# 2   A2   B2   C2   D2  B2  D2  F2
# 3   A3   B3   C3   D3  B3  D3  F3
# 6  NaN  NaN  NaN  NaN  B6  D6  F6
# 7  NaN  NaN  NaN  NaN  B7  D7  F7

# %% [markdown]
# ### b. merge() for combining dataframes using SQL like joins
#
# - Another ubiquitous operation related to DataFrames is the merging operation.
# - Two DataFrames might hold different kinds of information about the same entity and linked by some common feature/column.
# - We can use **merge()** to combine such dataframes in pandas.
#
# #### Creating dummy data

# %%
# joins - joining two or more tables on the basis of some common link/column

# %%
# create dummy data
df_a = pd.DataFrame({
        'subject_id': ['1', '2', '3', '4', '5'],
        'first_name': ['Alex', 'Amy', 'Allen', 'Alice', 'Ayoung'],
        'last_name': ['Anderson', 'Ackerman', 'Ali', 'Aoni', 'Atiches']})

df_b = pd.DataFrame({
        'subject_id': ['4', '5', '6', '7', '8'],
        'first_name': ['Billy', 'Brian', 'Bran', 'Bryce', 'Betty'],
        'last_name': ['Bonder', 'Black', 'Balwner', 'Brice', 'Btisan']})

df_c = pd.DataFrame({
        'subject_id': ['1', '2', '3', '4', '5', '7', '8', '9', '10', '11'],
        'test_id': [51, 15, 15, 61, 16, 14, 15, 1, 61, 16]})

# %% [markdown]
# Now these are our dataframes:
# ![](https://i.imgur.com/7TwI8cO.png)
#
# - Let's start with a basic join, we want to combine `df_a` with `df_c` based on the `subject_id` column.

# %%
df_a
# Out:
#   subject_id first_name last_name
# 0          1       Alex  Anderson
# 1          2        Amy  Ackerman
# 2          3      Allen       Ali
# 3          4      Alice      Aoni
# 4          5     Ayoung   Atiches

# %%
df_c
# Out:
#   subject_id  test_id
# 0          1       51
# 1          2       15
# 2          3       15
# 3          4       61
# 4          5       16
# 5          7       14
# 6          8       15
# 7          9        1
# 8         10       61
# 9         11       16

# %%
# select e.*, d.*  from
# Emp e join Dept d
# on e.dept_id = d.id

pd.merge(df_a, df_c, on = 'subject_id')
# Out:
#   subject_id first_name last_name  test_id
# 0          1       Alex  Anderson       51
# 1          2        Amy  Ackerman       15
# 2          3      Allen       Ali       15
# 3          4      Alice      Aoni       61
# 4          5     Ayoung   Atiches       16

# %%
df_c.rename(columns = {"subject_id":'id'}, inplace = True)
df_c.head(1)
# Out:
#   id  test_id
# 0  1       51

# %%
display(df_a.head(1))
display(df_c.head(1))
# Out:
#   subject_id first_name last_name
# 0          1       Alex  Anderson
#   id  test_id
# 0  1       51

# %%
pd.merge(df_a, df_c, left_on = 'subject_id', right_on = 'id')
# Out:
#   subject_id first_name last_name id  test_id
# 0          1       Alex  Anderson  1       51
# 1          2        Amy  Ackerman  2       15
# 2          3      Allen       Ali  3       15
# 3          4      Alice      Aoni  4       61
# 4          5     Ayoung   Atiches  5       16

# %%
# a = df_a.merge(df_c, on = 'subject_id')
# final = a.merge(df3, on = 'id').merge(df4, on = 'id2')|

# %%
|# pandas.merge(left, right, how='inner', on=None, left_on=None, right_on=None, left_index=False,
#  right_index=False, sort=False, suffixes=('_x', '_y'), copy=None, indicator=False, validate=None)[source]

# %%
# inner/outer/left/right
pd.merge(df_a, df_c, on = 'subject_id', how = 'inner')
# Out:
#   subject_id first_name last_name  test_id
# 0          1       Alex  Anderson       51
# 1          2        Amy  Ackerman       15
# 2          3      Allen       Ali       15
# 3          4      Alice      Aoni       61
# 4          5     Ayoung   Atiches       16

# %%
# id -
# EMPloyee_ID - Department

# select
# from employee e join Department d
# on e.id = d.EMPloyee_ID

# on a.emp_id = b.EMPloyee_ID


# pd.merge(a,b, left_on = 'emp_id' ,right_on = 'EMPloyee_ID', how= '')

# left_on = 'emp_id' ,right_on = 'EMP_ID'

# %%
pd.merge(df_a, df_c, left_on = 'subject_id', right_on = 'subject_id', how = 'inner')
# Out:
#   subject_id first_name last_name  test_id
# 0          1       Alex  Anderson       51
# 1          2        Amy  Ackerman       15
# 2          3      Allen       Ali       15
# 3          4      Alice      Aoni       61
# 4          5     Ayoung   Atiches       16

# %% [markdown]
# - Now that we have done a basic join, let's get into **some commmon SQL joins.**
#
# #### Merge with outer join
#
# - “Full outer join produces the set of all records in Table A and Table B, with matching records from both sides where available. If there is no match, the missing side will contain null.”
# ![](https://i.imgur.com/v4dsyRM.png)

# %%
pd.merge(df_a, df_c, on='subject_id', how='outer')
# Out:
#   subject_id first_name last_name  test_id
# 0          1       Alex  Anderson       51
# 1         10        NaN       NaN       61
# 2         11        NaN       NaN       16
# 3          2        Amy  Ackerman       15
# 4          3      Allen       Ali       15
# 5          4      Alice      Aoni       61
# 6          5     Ayoung   Atiches       16
# 7          7        NaN       NaN       14
# 8          8        NaN       NaN       15
# 9          9        NaN       NaN        1

# %% [markdown]
# #### Merge with inner join
#
# - “Inner join produces only the set of records that match in both Table A and Table B.”
# ![](https://i.imgur.com/EtsMTiY.png)

# %%
pd.merge(df_a, df_c, on='subject_id', how='inner')
# Out:
#   subject_id first_name last_name  test_id
# 0          1       Alex  Anderson       51
# 1          2        Amy  Ackerman       15
# 2          3      Allen       Ali       15
# 3          4      Alice      Aoni       61
# 4          5     Ayoung   Atiches       16

# %% [markdown]
# #### Merge with right join
#
# - “Right outer join produces a complete set of records from Table B, with the matching records (where available) in Table A. If there is no match, the left side will contain null.”
#
# ![](https://i.imgur.com/92C7G1Y.png)

# %%
pd.merge(df_a, df_c, on='subject_id', how='right')
# Out:
#   subject_id first_name last_name  test_id
# 0          1       Alex  Anderson       51
# 1          2        Amy  Ackerman       15
# 2          3      Allen       Ali       15
# 3          4      Alice      Aoni       61
# 4          5     Ayoung   Atiches       16
# 5          7        NaN       NaN       14
# 6          8        NaN       NaN       15
# 7          9        NaN       NaN        1
# 8         10        NaN       NaN       61
# 9         11        NaN       NaN       16

# %% [markdown]
# #### Merge with left join
#
# - “Left outer join produces a complete set of records from Table A, with the matching records (where available) in Table B. If there is no match, the right side will contain null.”
# ![](https://i.imgur.com/hG7Aozu.png)

# %%
df_a.merge(df_c, on='subject_id', how='left')
# Out:
#   subject_id first_name last_name  test_id
# 0          1       Alex  Anderson       51
# 1          2        Amy  Ackerman       15
# 2          3      Allen       Ali       15
# 3          4      Alice      Aoni       61
# 4          5     Ayoung   Atiches       16

# %%
pd.merge(df_a, df_c, on='subject_id', how='left')
# Out:
#   subject_id first_name last_name  test_id
# 0          1       Alex  Anderson       51
# 1          2        Amy  Ackerman       15
# 2          3      Allen       Ali       15
# 3          4      Alice      Aoni       61
# 4          5     Ayoung   Atiches       16

# %%
temp = df_a.merge(df_c, on = 'subject_id', how = "inner")
temp
# Out:
#   subject_id first_name last_name  test_id
# 0          1       Alex  Anderson       51
# 1          2        Amy  Ackerman       15
# 2          3      Allen       Ali       15
# 3          4      Alice      Aoni       61
# 4          5     Ayoung   Atiches       16

# %%
# temp = pd.merge(a,b, on = "id")
# merged = pd.merge(temp, c, on = "id2")

# merged

# pd.merge(emp, dept, on = '')
# emp.merge(dept, on = '', how= '')

# %%
pd.merge(df_a, df_c, on = 'subject_id', how="inner")
# Out:
#   subject_id first_name last_name  test_id
# 0          1       Alex  Anderson       51
# 1          2        Amy  Ackerman       15
# 2          3      Allen       Ali       15
# 3          4      Alice      Aoni       61
# 4          5     Ayoung   Atiches       16

# %%
df_a.merge(df_c, on = 'subject_id', how="inner")
# Out:
#   subject_id first_name last_name  test_id
# 0          1       Alex  Anderson       51
# 1          2        Amy  Ackerman       15
# 2          3      Allen       Ali       15
# 3          4      Alice      Aoni       61
# 4          5     Ayoung   Atiches       16

# %%
# df1, df2, df3


# merged = pd.merge(df1, df2, on = '')
# final = pd.merge(merged, df3, on = '')

# %%
df_a.merge(df_c, on = 'subject_id')
# Out:
#   subject_id first_name last_name  test_id
# 0          1       Alex  Anderson       51
# 1          2        Amy  Ackerman       15
# 2          3      Allen       Ali       15
# 3          4      Alice      Aoni       61
# 4          5     Ayoung   Atiches       16

# %% [markdown]
# ### Merge OR Concat : Which to use when?
#
# 1. After learning both of the functions in detail, chances are that you might be confused which to use when.
# 2. One major difference is that `merge()` is used to combine dataframes on the basis of values of **common columns**. While`concat()` is used to **append dataframes** one below the other (or sideways, depending on whether the axis option is set to 0 or 1).
# 3. Exact usage depends upon the kind of data you have and analysis you want to perform.

# %% [markdown]
# ### Aggregating data
#
# There are multiple functions that can be used to perform useful aggregations on data in pandas:
#
#  - groupby
#  - crosstab
#  - pivottable
#
# #### a. **What is the mean price for each item type?** : groupby
# - In the given data set, I want to find out **what is the mean price for each item type**?
# - You can use **groupby()** to achieve this.
# - The first step would be to group the data by Item_Type column.

# %%
df.groupby(['Outlet_Size','Outlet_Location_Type']).agg({"Item_MRP":'mean', "Item_Outlet_Sales":'sum'})
# Out:
#                                     Item_MRP  Item_Outlet_Sales
# Outlet_Size Outlet_Location_Type
# High        Tier 3                141.425982       2.142664e+06
# Medium      Tier 1                140.297699       2.183970e+06
#             Tier 3                140.736687       5.305749e+06
# Small       Tier 1                141.235221       2.298089e+06
#             Tier 2                143.122481       2.268123e+06

# %%
df.head(1)
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility Item_Type  \
# 0           FDA15          9.3          Low Fat         0.016047     Dairy
#
#    Item_MRP Outlet_Identifier  Outlet_Establishment_Year Outlet_Size  \
# 0  249.8092            OUT049                       1999      Medium
#
#   Outlet_Location_Type        Outlet_Type  Item_Outlet_Sales
# 0               Tier 1  Supermarket Type1           3735.138

# %%
df.groupby(['Outlet_Size', 'Outlet_Location_Type']).agg({'Item_MRP':'mean',
                                      'Item_Outlet_Sales':'sum',
                                                         'Item_Identifier':'nunique'}).reset_index()
# Out:
#   Outlet_Size Outlet_Location_Type    Item_MRP  Item_Outlet_Sales  \
# 0        High               Tier 3  141.425982       2.142664e+06
# 1      Medium               Tier 1  140.297699       2.183970e+06
# 2      Medium               Tier 3  140.736687       5.305749e+06
# 3       Small               Tier 1  141.235221       2.298089e+06
# 4       Small               Tier 2  143.122481       2.268123e+06
#
#    Item_Identifier
# 0              932
# 1              930
# 2             1304
# 3             1150
# 4              930

# %%
#Item_Type , Avg Item_MRP, sum Item_MRP
#  same coln -> multiple agg func


# select Item_Type, average(Item_MRP), sum(Item_MRP), sum(Item_Outlet_Sales)
# from table
# group by Item_Type



df.groupby(['Item_Type']).agg({'Item_MRP':['mean', 'sum'],
                                      'Item_Outlet_Sales':'sum'})
# Out:
#                          Item_MRP              Item_Outlet_Sales
#                              mean          sum               sum
# Item_Type
# Baking Goods           126.380766   81894.7364      1.265525e+06
# Breads                 140.952669   35379.1198      5.532372e+05
# Breakfast              141.788151   15596.6966      2.322990e+05
# Canned                 139.763832   90706.7270      1.444151e+06
# Dairy                  148.499208  101276.4596      1.522594e+06
# Frozen Foods           138.503366  118558.8814      1.825735e+06
# Fruits and Vegetables  144.581235  178124.0810      2.820060e+06
# Hard Drinks            137.077928   29334.6766      4.577934e+05
# Health and Hygiene     130.818921   68025.8388      1.045200e+06
# Household              149.424753  135976.5254      2.055494e+06
# Meat                   139.882032   59449.8638      9.175656e+05
# Others                 132.851430   22451.8916      3.255176e+05
# Seafood                141.841719    9077.8700      1.488682e+05
# Snack Foods            146.194934  175433.9204      2.732786e+06
# Soft Drinks            131.492506   58514.1650      8.928977e+05
# Starchy Foods          147.838023   21880.0274      3.514013e+05

# %%
df.groupby(['col1', 'col2']).agg({'agg_col1':['mean', 'count', 'sum'],
                                  "agg_col2": "sum",
                                  'cat_col1': 'nunique'})

# %%
# What is the mean price for each item type?
# SQL:
# Select item_type , average(ITEM_MRP)
# from table
# groupby item_type



# Pandas
df.groupby("Item_Type").Item_MRP.mean()
# Out:
# Item_Type
# Baking Goods             125.795653
# Breads                   141.300639
# Breakfast                134.090683
# Canned                   138.551179
# Dairy                    149.481471
# Frozen Foods             140.095830
# Fruits and Vegetables    145.418257
# Hard Drinks              140.102908
# Health and Hygiene       131.437324
# Household                149.884244
# Meat                     140.279344
# Others                   137.640870
# Seafood                  146.595782
# Snack Foods              147.569955
# Soft Drinks              130.910182
# Starchy Foods            151.256747
# Name: Item_MRP, dtype: float64

# %%
df.head(1)
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility Item_Type  \
# 0           FDA15          9.3          Low Fat         0.016047     Dairy
#
#    Item_MRP Outlet_Identifier  Outlet_Establishment_Year Outlet_Size  \
# 0  249.8092            OUT049                       1999      Medium
#
#   Outlet_Location_Type        Outlet_Type  Item_Outlet_Sales  quantity  \
# 0               Tier 1  Supermarket Type1           3735.138      15.0
#
#    Item_MRP_clipped  Item_MRP_using_apply
# 0             200.0                 200.0

# %%
df.Outlet_Size.unique()
# Out:
# array(['Medium', 'High', 'Small'], dtype=object)

# %%
# Item_Type wise average MRP, avergae sales
df.groupby(['Item_Type', 'Outlet_Size']).agg({'Item_MRP':'mean',
                                              'Item_Outlet_Sales': 'mean'
                                              })
# Out:
#                                      Item_MRP  Item_Outlet_Sales
# Item_Type             Outlet_Size
# Baking Goods          High         129.202044        2050.901134
#                       Medium       124.823967        1942.749745
#                       Small        124.973010        2141.541076
# Breads                High         133.758960        2080.731528
#                       Medium       137.990438        2213.375277
#                       Small        147.858320        2696.853164
# Breakfast             High         147.490585        2104.286508
#                       Medium       129.017096        2108.428808
#                       Small        131.722730        2385.861010
# Canned                High         135.442708        2211.265203
#                       Medium       136.883055        1957.378532
#                       Small        141.491103        2440.589109
# Dairy                 High         153.509173        2453.181713
#                       Medium       148.722985        2197.426603
#                       Small        148.087613        2417.139981
# Frozen Foods          High         136.829250        2214.096189
#                       Medium       142.196088        2159.344154
#                       Small        139.655719        2283.620762
# Fruits and Vegetables High         145.572870        2405.118103
#                       Medium       141.926119        2192.620852
#                       Small        149.070800        2389.799021
# Hard Drinks           High         141.927522        2363.590000
#                       Medium       142.510904        2161.020350
#                       Small        136.122386        2251.370995
# Health and Hygiene    High         135.110980        1953.042439
#                       Medium       129.165200        2015.364495
#                       Small        131.681104        2371.887375
# Household             High         147.097522        2408.217992
#                       Medium       148.327454        2374.130665
#                       Small        152.727281        2387.185302
# Meat                  High         137.244790        2321.953141
#                       Medium       134.336873        2148.443531
#                       Small        148.061717        2324.897071
# Others                High         132.576613        2202.383175
#                       Medium       136.372854        2293.105173
#                       Small        141.007837        2094.431589
# Seafood               High         134.864240        1629.345760
#                       Medium       149.272286        2428.125043
#                       Small        148.109114        3548.095757
# Snack Foods           High         145.847086        2473.968987
#                       Medium       150.904812        2320.880527
#                       Small        144.922309        2424.567037
# Soft Drinks           High         131.758473        2351.727890
#                       Medium       130.693859        2022.620793
#                       Small        130.693536        1928.156800
# Starchy Foods         High         158.157074        2302.791947
#                       Medium       150.618788        2209.731453
#                       Small        148.038641        2858.964782

# %%
# Item_Type wise average MRP, avergae sales
df.groupby(['Item_Type', 'Outlet_Size']).agg({'Item_MRP':'mean',
                                              'Item_Outlet_Sales': ['mean', 'sum'],
                                              })
# Out:
#                                      Item_MRP Item_Outlet_Sales
#                                          mean              mean          sum
# Item_Type             Outlet_Size
# Baking Goods          High         129.202044       2050.901134  149715.7828
#                       Medium       124.823967       1942.749745  260328.4658
#                       Small        124.973010       2141.541076  308381.9150
# Breads                High         133.758960       2080.731528   52018.2882
#                       Medium       137.990438       2213.375277  115095.5144
#                       Small        147.858320       2696.853164  148326.9240
# Breakfast             High         147.490585       2104.286508   27355.7246
#                       Medium       129.017096       2108.428808   52710.7202
#                       Small        131.722730       2385.861010   47717.2202
# Canned                High         135.442708       2211.265203  143732.2382
#                       Medium       136.883055       1957.378532  283819.8872
#                       Small        141.491103       2440.589109  368528.9554
# Dairy                 High         153.509173       2453.181713  196254.5370
#                       Medium       148.722985       2197.426603  331811.4170
#                       Small        148.087613       2417.139981  360153.8572
# Frozen Foods          High         136.829250       2214.096189  203696.8494
#                       Medium       142.196088       2159.344154  399478.6684
#                       Small        139.655719       2283.620762  456724.1524
# Fruits and Vegetables High         145.572870       2405.118103  341526.7706
#                       Medium       141.926119       2192.620852  598585.4926
#                       Small        149.070800       2389.799021  609398.7504
# Hard Drinks           High         141.927522       2363.590000   54362.5700
#                       Medium       142.510904       2161.020350  112373.0582
#                       Small        136.122386       2251.370995   94557.5818
# Health and Hygiene    High         135.110980       1953.042439  119135.5888
#                       Medium       129.165200       2015.364495  221690.0944
#                       Small        131.681104       2371.887375  251420.0618
# Household             High         147.097522       2408.217992  248046.4532
#                       Medium       148.327454       2374.130665  451084.8264
#                       Small        152.727281       2387.185302  489372.9870
# Meat                  High         137.244790       2321.953141   95200.0788
#                       Medium       134.336873       2148.443531  199805.2484
#                       Small        148.061717       2324.897071  202266.0452
# Others                High         132.576613       2202.383175   35238.1308
#                       Medium       136.372854       2293.105173   84844.8914
#                       Small        141.007837       2094.431589   79588.4004
# Seafood               High         134.864240       1629.345760    8146.7288
#                       Medium       149.272286       2428.125043   33993.7506
#                       Small        148.109114       3548.095757   49673.3406
# Snack Foods           High         145.847086       2473.968987  309246.1234
#                       Medium       150.904812       2320.880527  628958.6228
#                       Small        144.922309       2424.567037  630387.4296
# Soft Drinks           High         131.758473       2351.727890  115234.6666
#                       Medium       130.693859       2022.620793  186081.1130
#                       Small        130.693536       1928.156800  192815.6800
# Starchy Foods         High         158.157074       2302.791947   43753.0470
#                       Medium       150.618788       2209.731453   75130.8694
#                       Small        148.038641       2858.964782   97204.8026

# %%
df.groupby(['Outlet_Location_Type', 'Outlet_Type']).agg({'Item_MRP': 'mean', 'Item_Outlet_Sales':'mean'})
# Out:
#                                           Item_MRP  Item_Outlet_Sales
# Outlet_Location_Type Outlet_Type
# Tier 1               Supermarket Type1  141.177543        2313.099451
# Tier 2               Supermarket Type1  143.122481        2438.841866
# Tier 3               Supermarket Type1  141.425982        2298.995256
#                      Supermarket Type2  141.678634        1995.498739

# %%
# multiple agg fns on same cols
df.groupby(['Outlet_Location_Type', 'Outlet_Type']).agg({'Item_MRP':['mean', 'sum']}).reset_index()
# Out:
#   Outlet_Location_Type        Outlet_Type    Item_MRP
#                                                  mean          sum
# 0               Tier 1      Grocery Store  139.787088   73807.5824
# 1               Tier 1  Supermarket Type1  141.177543  262590.2296
# 2               Tier 2  Supermarket Type1  141.167196  393150.6416
# 3               Tier 3      Grocery Store  140.777594   78131.5646
# 4               Tier 3  Supermarket Type1  141.425982  131809.0156
# 5               Tier 3  Supermarket Type2  141.678634  131477.7724
# 6               Tier 3  Supermarket Type3  139.801791  130714.6746

# %%
import pandas as pd
import numpy as np

# # read the dataset
data_BM = pd.read_csv('/content/drive/MyDrive/bigmart_data.csv')
# # drop the null values
data_BM = data_BM.dropna(how="any")
# # reset index after dropping
data_BM = data_BM.reset_index(drop=True)
# # view the top results
data_BM.head()
# df.shape
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15        9.300          Low Fat         0.016047
# 1           DRC01        5.920          Regular         0.019278
# 2           FDN15       17.500          Low Fat         0.016760
# 3           NCD19        8.930          Low Fat         0.000000
# 4           FDP36       10.395          Regular         0.000000
#
#       Item_Type  Item_MRP Outlet_Identifier  Outlet_Establishment_Year  \
# 0         Dairy  249.8092            OUT049                       1999
# 1   Soft Drinks   48.2692            OUT018                       2009
# 2          Meat  141.6180            OUT049                       1999
# 3     Household   53.8614            OUT013                       1987
# 4  Baking Goods   51.4008            OUT018                       2009
#
#   Outlet_Size Outlet_Location_Type        Outlet_Type  Item_Outlet_Sales
# 0      Medium               Tier 1  Supermarket Type1          3735.1380
# 1      Medium               Tier 3  Supermarket Type2           443.4228
# 2      Medium               Tier 1  Supermarket Type1          2097.2700
# 3        High               Tier 3  Supermarket Type1           994.7052
# 4      Medium               Tier 3  Supermarket Type2           556.6088

# %% [markdown]
# #### Group By
#
# Pandas groupby is used for grouping the data according to the categories and apply a function to the categories. It also helps to aggregate data efficiently.
#
# Pandas dataframe.groupby() function is used to split the data into groups based on some criteria. pandas objects can be split on any of their axes. The abstract definition of grouping is to provide a mapping of labels to group names.
#
#     Syntax: DataFrame.groupby(by=None, axis=0, level=None, as_index=True, sort=True, group_keys=True, squeeze=False, **kwargs)
#
#     Parameters :
#     by : mapping, function, str, or iterable
#     axis : int, default 0
#     level : If the axis is a MultiIndex (hierarchical), group by a particular level or levels
#     as_index : For aggregated output, return object with group labels as the index.
#     Only relevant for DataFrame input. as_index=False is effectively “SQL-style” grouped output
#     sort : Sort group keys. Get better performance by turning this off. Note this does not
#     influence the order of observations within each group. groupby preserves the order of
#     rows within each group.
#     group_keys : When calling apply, add group keys to index to identify pieces
#     squeeze : Reduce the dimensionality of the return type if possible,
#     otherwise return a consistent type
#
#     Returns : GroupBy object

# %%
# data_BM.groupby('Item_Type').Item_MRP.mean().reset_index()
data_BM.groupby("Item_Type").agg({'Item_MRP':'mean'})
# Out:
#                          Item_MRP
# Item_Type
# Baking Goods           125.795653
# Breads                 141.300639
# Breakfast              134.090683
# Canned                 138.551179
# Dairy                  149.481471
# Frozen Foods           140.095830
# Fruits and Vegetables  145.418257
# Hard Drinks            140.102908
# Health and Hygiene     131.437324
# Household              149.884244
# Meat                   140.279344
# Others                 137.640870
# Seafood                146.595782
# Snack Foods            147.569955
# Soft Drinks            130.910182
# Starchy Foods          151.256747

# %%
# mean price for each item type? from table
# select item_type, avg(mrp) from table
# group by item_type;

avg_price_per_item = data_BM.groupby('Item_Type').Item_MRP.mean().reset_index()
avg_price_per_item
# Out:
#                 Item_Type    Item_MRP
# 0            Baking Goods  125.795653
# 1                  Breads  141.300639
# 2               Breakfast  134.090683
# 3                  Canned  138.551179
# 4                   Dairy  149.481471
# 5            Frozen Foods  140.095830
# 6   Fruits and Vegetables  145.418257
# 7             Hard Drinks  140.102908
# 8      Health and Hygiene  131.437324
# 9               Household  149.884244
# 10                   Meat  140.279344
# 11                 Others  137.640870
# 12                Seafood  146.595782
# 13            Snack Foods  147.569955
# 14            Soft Drinks  130.910182
# 15          Starchy Foods  151.256747

# %%
# top 5 categories in terms of avg mrp
data_BM.groupby('Item_Type').Item_MRP.mean().reset_index().sort_values(by = 'Item_MRP', ascending = False).head(5).style.background_gradient(cmap = 'rainbow')
# Out:
# <style type="text/css">
# #T_2dfa9_row0_col1 {
#   background-color: #ff0000;
#   color: #f1f1f1;
# }
# #T_2dfa9_row1_col1 {
#   background-color: #e8cb72;
#   color: #000000;
# }
# #T_2dfa9_row2_col1 {
#   background-color: #bced8f;
#   color: #000000;
# }
# #T_2dfa9_row3_col1 {
#   background-color: #169bf2;
#   color: #f1f1f1;
# }
# #T_2dfa9_row4_col1 {
#   background-color: #8000ff;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_2dfa9" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2dfa9_level0_col0" class="col_heading level0 col0" >Item_Type</th>
#       <th id="T_2dfa9_level0_col1" class="col_heading level0 col1" >Item_MRP</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2dfa9_level0_row0" class="row_heading level0 row0" >15</th>
#       <td id="T_2dfa9_row0_col0" class="data row0 col0" >Starchy Foods</td>
#       <td id="T_2dfa9_row0_col1" class="data row0 col1" >151.256747</td>
#     </tr>
#     <tr>
#       <th id="T_2dfa9_level0_row1" class="row_heading level0 row1" >9</th>
#       <td id="T_2dfa9_row1_col0" class="data row1 col0" >Household</td>
#       <td id="T_2dfa9_row1_col1" class="data row1 col1" >149.884244</td>
#     </tr>
#     <tr>
#       <th id="T_2dfa9_level0_row2" class="row_heading level0 row2" >4</th>
#       <td id="T_2dfa9_row2_col0" class="data row2 col0" >Dairy</td>
#       <td id="T_2dfa9_row2_col1" class="data row2 col1" >149.481471</td>
#     </tr>
#     <tr>
#       <th id="T_2dfa9_level0_row3" class="row_heading level0 row3" >13</th>
#       <td id="T_2dfa9_row3_col0" class="data row3 col0" >Snack Foods</td>
#       <td id="T_2dfa9_row3_col1" class="data row3 col1" >147.569955</td>
#     </tr>
#     <tr>
#       <th id="T_2dfa9_level0_row4" class="row_heading level0 row4" >12</th>
#       <td id="T_2dfa9_row4_col0" class="data row4 col0" >Seafood</td>
#       <td id="T_2dfa9_row4_col1" class="data row4 col1" >146.595782</td>
#     </tr>
#   </tbody>
# </table>

# %%
data_BM.groupby('Item_Type').Item_MRP.mean().reset_index().sort_values(by = 'Item_MRP', ascending = False).rename(columns = {"Item_MRP": "Avg_Item_MRP"}).reset_index()
# Out:
#     index              Item_Type  Avg_Item_MRP
# 0      15          Starchy Foods    151.256747
# 1       9              Household    149.884244
# 2       4                  Dairy    149.481471
# 3      13            Snack Foods    147.569955
# 4      12                Seafood    146.595782
# 5       6  Fruits and Vegetables    145.418257
# 6       1                 Breads    141.300639
# 7      10                   Meat    140.279344
# 8       7            Hard Drinks    140.102908
# 9       5           Frozen Foods    140.095830
# 10      3                 Canned    138.551179
# 11     11                 Others    137.640870
# 12      2              Breakfast    134.090683
# 13      8     Health and Hygiene    131.437324
# 14     14            Soft Drinks    130.910182
# 15      0           Baking Goods    125.795653

# %%
# group price based on item type # mean price by item
# price_by_item = data_BM.groupby('Item_Type')['Item_MRP'].mean()

# display first few rows

# %% [markdown]
# - Now that you have grouped by Item_Type, the next step would be to calculate the mean of Item_MRP.

# %% [markdown]
# - You can use `groupby` with **multiple** columns of the dataset too.
# - In this case, if you want to group first based on the Item_Type and then Item_MRP you can simply pass a list of column names.

# %%
data_BM.head(2)
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility    Item_Type  \
# 0           FDA15         9.30          Low Fat         0.016047        Dairy
# 1           DRC01         5.92          Regular         0.019278  Soft Drinks
#
#    Item_MRP Outlet_Identifier  Outlet_Establishment_Year Outlet_Size  \
# 0  249.8092            OUT049                       1999      Medium
# 1   48.2692            OUT018                       2009      Medium
#
#   Outlet_Location_Type        Outlet_Type  Item_Outlet_Sales
# 0               Tier 1  Supermarket Type1          3735.1380
# 1               Tier 3  Supermarket Type2           443.4228

# %%
# Avg Item_Outlet_Sales across all Outlet_Types
data_BM.groupby('Outlet_Type').agg({"Item_Outlet_Sales":"mean"})
# Out:
#                    Item_Outlet_Sales
# Outlet_Type
# Supermarket Type1        2340.986430
# Supermarket Type2        1995.498739

# %%
# Avg, total of  Item_Outlet_Sales across all Outlet_Types
data_BM.groupby('Outlet_Type').agg({"Item_Outlet_Sales":["mean", 'sum']})
# Out:
#                   Item_Outlet_Sales
#                                mean          sum
# Outlet_Type
# Supermarket Type1       2340.986430  8713151.492
# Supermarket Type2       1995.498739  1851822.830

# %%
# grouping on multiple columns:  Item_Type, Outlet_Size
data_BM.groupby(['Item_Type', 'Outlet_Size']).agg({"Item_MRP":"mean"})
# Out:
#                                      Item_MRP
# Item_Type             Outlet_Size
# Baking Goods          High         129.202044
#                       Medium       124.823967
#                       Small        124.973010
# Breads                High         133.758960
#                       Medium       137.990438
#                       Small        147.858320
# Breakfast             High         147.490585
#                       Medium       129.017096
#                       Small        131.722730
# Canned                High         135.442708
#                       Medium       136.883055
#                       Small        141.491103
# Dairy                 High         153.509173
#                       Medium       148.722985
#                       Small        148.087613
# Frozen Foods          High         136.829250
#                       Medium       142.196088
#                       Small        139.655719
# Fruits and Vegetables High         145.572870
#                       Medium       141.926119
#                       Small        149.070800
# Hard Drinks           High         141.927522
#                       Medium       142.510904
#                       Small        136.122386
# Health and Hygiene    High         135.110980
#                       Medium       129.165200
#                       Small        131.681104
# Household             High         147.097522
#                       Medium       148.327454
#                       Small        152.727281
# Meat                  High         137.244790
#                       Medium       134.336873
#                       Small        148.061717
# Others                High         132.576613
#                       Medium       136.372854
#                       Small        141.007837
# Seafood               High         134.864240
#                       Medium       149.272286
#                       Small        148.109114
# Snack Foods           High         145.847086
#                       Medium       150.904812
#                       Small        144.922309
# Soft Drinks           High         131.758473
#                       Medium       130.693859
#                       Small        130.693536
# Starchy Foods         High         158.157074
#                       Medium       150.618788
#                       Small        148.038641

# %%
data_BM.groupby(['Item_Type']).agg({"Item_Weight":["mean", 'sum', 'max', 'min'], 'Item_MRP': "max"}).reset_index()
# Out:
#                 Item_Type Item_Weight                          Item_MRP
#                                  mean       sum    max    min       max
# 0            Baking Goods   12.336923  4330.260  20.85  4.880  265.5568
# 1                  Breads   11.190000  1477.080  20.85  4.635  263.2594
# 2               Breakfast   12.649397   733.665  21.10  6.425  232.7326
# 3                  Canned   12.304557  4441.945  21.35  4.615  266.8884
# 4                   Dairy   13.504276  5131.625  20.70  4.805  266.1884
# 5            Frozen Foods   12.854832  6131.755  20.85  4.555  264.8910
# 6   Fruits and Vegetables   13.196813  8841.865  21.35  5.460  263.9252
# 7             Hard Drinks   11.449060  1339.540  19.70  4.610  261.4278
# 8      Health and Hygiene   13.274946  3677.160  21.25  5.175  266.6884
# 9               Household   13.634347  6789.905  21.25  5.030  263.9910
# 10                   Meat   12.743009  2816.205  21.25  5.150  260.2936
# 11                 Others   13.749286  1251.185  20.50  5.500  254.9040
# 12                Seafood   13.360909   440.910  20.75  5.365  240.2880
# 13            Snack Foods   12.983643  8517.270  21.25  5.095  264.9568
# 14            Soft Drinks   11.886328  2864.605  20.75  4.590  263.3910
# 15          Starchy Foods   13.722586  1193.865  21.20  6.695  263.0252

# %%
# select col1, col2 , avg(col3), sum(col3), count(col4)
# from table1
# group by col1, col2

# aggregation function on multiple numeric columns : Item_MRP, Item_Outlet_Sales

# %%
# data_BM.groupby(['Item_Type']).agg({'Item_MRP':['mean', 'sum', 'count'], 'Item_Outlet_Sales':'mean'})

# %%
# data_BM.groupby(['Item_Type']).agg({'Item_MRP':['mean', 'count'], 'Item_Outlet_Sales':['mean','sum']}).reset_index()

# %%
data_BM.groupby(['Item_Type']).Item_MRP.mean().reset_index().rename(columns = {'Item_MRP': 'Avg_Item_MRP'})
# Out:
#                 Item_Type  Avg_Item_MRP
# 0            Baking Goods    125.795653
# 1                  Breads    141.300639
# 2               Breakfast    134.090683
# 3                  Canned    138.551179
# 4                   Dairy    149.481471
# 5            Frozen Foods    140.095830
# 6   Fruits and Vegetables    145.418257
# 7             Hard Drinks    140.102908
# 8      Health and Hygiene    131.437324
# 9               Household    149.884244
# 10                   Meat    140.279344
# 11                 Others    137.640870
# 12                Seafood    146.595782
# 13            Snack Foods    147.569955
# 14            Soft Drinks    130.910182
# 15          Starchy Foods    151.256747

# %%
# result = df.groupby('Category').agg({
#     'Value': ['sum', 'mean']
# })

# %%
df.head(1)
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility Item_Type  \
# 0           FDA15          9.3          Low Fat         0.016047     Dairy
#
#    Item_MRP Outlet_Identifier  Outlet_Establishment_Year Outlet_Size  \
# 0  249.8092            OUT049                       1999      Medium
#
#   Outlet_Location_Type        Outlet_Type  Item_Outlet_Sales  quantity  \
# 0               Tier 1  Supermarket Type1           3735.138      15.0
#
#    Item_MRP_clipped  Item_MRP_using_apply
# 0             200.0                 200.0

# %%
# Outlet_Size x Outlet_Location_Type
df.groupby(['Outlet_Size','Outlet_Location_Type']).agg({'Item_MRP':'mean','quantity': 'sum',
                                                         'Item_Outlet_Sales': 'sum'}).reset_index().rename(columns = {'Item_MRP': 'Avg_Item_MRP',
                                                                                                                      'quantity':'Total_quantity'})
# Out:
#   Outlet_Size Outlet_Location_Type  Avg_Item_MRP  Total_quantity  \
# 0        High               Tier 3    141.425982         14910.0
# 1      Medium               Tier 1    140.297699         15472.0
# 2      Medium               Tier 3    141.678634         12859.0
# 3       Small               Tier 1    142.057387         15054.0
# 4       Small               Tier 2    143.122481         15779.0
#
#    Item_Outlet_Sales
# 0       2.142664e+06
# 1       2.183970e+06
# 2       1.851823e+06
# 3       2.118395e+06
# 4       2.268123e+06

# %% [markdown]
# You can read more about **groupby** and other related functions [here.](http://pandas.pydata.org/pandas-docs/stable/user_guide/groupby.html)
#
#
# #### Crosstab
#
# This method is used to compute a simple cross-tabulation of two (or more) factors. By default, computes a frequency table of the factors unless an array of values and an aggregation function are passed.
#
#     Syntax: pandas.crosstab(index, columns, values=None, rownames=None, colnames=None, aggfunc=None, margins=False, margins_name=’All’, dropna=True, normalize=False)
#
#     Arguments :
#
#         index : array-like, Series, or list of arrays/Series, Values to group by in the rows.
#         columns : array-like, Series, or list of arrays/Series, Values to group by in the columns.
#         values : array-like, optional, array of values to aggregate according to the factors. Requires `aggfunc` be specified.
#         rownames : sequence, default None, If passed, must match number of row arrays passed.
#         colnames : sequence, default None, If passed, must match number of column arrays passed.
#         aggfunc : function, optional, If specified, requires `values` be specified as well.
#         margins : bool, default False, Add row/column margins (subtotals).
#         margins_name : str, default ‘All’, Name of the row/column that will contain the totals when margins is True.
#         dropna : bool, default True, Do not include columns whose entries are all NaN.
#
# **b. How are outlet sizes distributed based on the city type?** : crosstab
#
# - This function is used to get an initial “feel” (view) of the data. Here, we can validate some basic hypothesis.
# - For example, in this case, "Outlet_Location_Type" is expected to affect the "Outlet_Size" significantly. This can be tested using cross-tabulation as shown below:

# %% [markdown]
# https://pandas.pydata.org/docs/reference/api/pandas.crosstab.html

# %%
data_BM = df.copy()

# %%
# generate crosstab of Outlet_Size and Outlet_Location_Type
# pd.crosstab(x,y)
pd.crosstab(data_BM["Outlet_Size"],data_BM["Outlet_Location_Type"])
# Out:
# Outlet_Location_Type  Tier 1  Tier 2  Tier 3
# Outlet_Size
# High                       0       0     932
# Medium                   930       0    1863
# Small                   1458     930       0

# %%
ct1 = pd.crosstab(data_BM["Outlet_Size"],data_BM["Outlet_Location_Type"], normalize=True)
ct1
# Out:
# Outlet_Location_Type    Tier 1    Tier 2    Tier 3
# Outlet_Size
# High                  0.000000  0.000000  0.152462
# Medium                0.152135  0.000000  0.304760
# Small                 0.238508  0.152135  0.000000

# %%
ct1.index
# Out:
# Index(['High', 'Medium', 'Small'], dtype='object', name='Outlet_Size')

# %%
df.head(3)
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility    Item_Type  \
# 0           FDA15         9.30          Low Fat         0.016047        Dairy
# 1           DRC01         5.92          Regular         0.019278  Soft Drinks
# 2           FDN15        17.50          Low Fat         0.016760         Meat
#
#    Item_MRP Outlet_Identifier  Outlet_Establishment_Year Outlet_Size  \
# 0  249.8092            OUT049                       1999      Medium
# 1   48.2692            OUT018                       2009      Medium
# 2  141.6180            OUT049                       1999      Medium
#
#   Outlet_Location_Type        Outlet_Type  Item_Outlet_Sales
# 0               Tier 1  Supermarket Type1          3735.1380
# 1               Tier 3  Supermarket Type2           443.4228
# 2               Tier 1  Supermarket Type1          2097.2700

# %%
pd.crosstab(data_BM["Outlet_Size"],data_BM["Outlet_Location_Type"], margins = True, normalize=True)
# Out:
# Outlet_Location_Type  Tier 1  Tier 2   Tier 3      All
# Outlet_Size
# High                     0.0     0.0  0.20043  0.20043
# Medium                   0.2     0.0  0.19957  0.39957
# Small                    0.2     0.2  0.00000  0.40000
# All                      0.4     0.2  0.40000  1.00000

# %% [markdown]
# - If you notice in the above `crosstab` there are interesting insights like 50% of medium size outlets are present only in either Tier 1 or Tier 3 cities.
# - Another counter intuitive thing to notice is that high outlet size is only present in Tier 3 city though general assumption would be towards Tier 1 cities having larger outlet sizes.
#
#
# #### pivottable
#
# pivottable create a spreadsheet-style pivot table as a DataFrame.
#
# Levels in the pivot table will be stored in MultiIndex objects (hierarchical indexes) on the index and columns of the result DataFrame.
#
#     Syntax:
#
#     pandas.pivot_table(data, values=None, index=None, columns=None, aggfunc=’mean’, fill_value=None, margins=False, dropna=True, margins_name=’All’)
#
#     Parameters:
#
#     data : DataFrame
#     values : column to aggregate, optional
#     index: column, Grouper, array, or list of the previous
#     columns: column, Grouper, array, or list of the previous
#
#     aggfunc: function, list of functions, dict, default numpy.mean
#     -> If list of functions passed, the resulting pivot table will have hierarchical columns whose top level are the function names.
#     -> If dict is passed, the key is column to aggregate and value is function or list of functions
#
#     fill_value[scalar, default None] : Value to replace missing values with
#     margins[boolean, default False] : Add all row / columns (e.g. for subtotal / grand totals)
#     dropna[boolean, default True] : Do not include columns whose entries are all NaN
#     margins_name[string, default ‘All’] : Name of the row / column that will contain the totals when margins is True.
#
# **c. How are the sales changing per year? :** pivottable
#
# - Pandas can be used to create MS Excel style pivot tables.
# - The fun thing about pandas `pivot_table` is you can get another point of view on your data with only one line of code.
# - Most of the `pivot_table` parameters use default values, so the only mandatory parameters you must add are `data` and `index`.
#     - **data** is self explanatory – it’s the DataFrame you’d like to use
#     - **index** is the column, grouper, array (or list of the previous) you’d like to group your data by.
#     - **values (optional)** is the column you’d like to aggregate. If you do not specify this then the function will aggregate all numeric columns.

# %% [markdown]
# https://pandas.pydata.org/docs/reference/api/pandas.pivot_table.html

# %%
# create pivot table
pd.pivot_table(data_BM, index=['Outlet_Location_Type'], values= "Item_Outlet_Sales")
# Out:
#                       Item_Outlet_Sales
# Outlet_Location_Type
# Tier 1                      1876.909159
# Tier 2                      2323.990559
# Tier 3                      2279.627651

# %% [markdown]
# - In the above example, the mean sales for each year is shown.
# - You can also pass multiple columns to pivot table, in the next exammple we try to see mean sales not just by the year but also taking into account the **outlet size** and type of the city.

# %%
# create pivot table
pd.pivot_table(data_BM, index=['Outlet_Size','Outlet_Establishment_Year'],
               values= "Item_Outlet_Sales")
# Out:
#                                        Item_Outlet_Sales
# Outlet_Size Outlet_Establishment_Year
# High        1987                             2298.995256
# Medium      1985                             3694.038558
#             1999                             2348.354635
#             2009                             1995.498739
# Small       1985                              340.329723
#             1997                             2277.844267
#             2004                             2438.841866

# %% [markdown]
# - This makes it easier to see that Tier 1 cities have good sales irrespective of year and outlet size.
# - We also notice that Tier 2 and Tier 3 cities dominate during the later years. This might mean both they are performing better or we have less data of later years.
# - You can also perform multiple aggregations like mean, median, min, max etc. in a pivot table by using **aggfunc** parameter.

# %%
import numpy as np
pd.pivot_table(data_BM, index=[ 'Outlet_Size'], columns = ['Outlet_Location_Type'],
               values= "Item_Outlet_Sales", aggfunc= [np.mean, np.median,np.min,np.max, 'sum'])
# Out:
# <ipython-input-43-cbbcc80c1005>:2: FutureWarning: The provided callable <function median at 0x7c3ce63831a0> is currently using DataFrameGroupBy.median. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "median" instead.
#   pd.pivot_table(data_BM, index=[ 'Outlet_Size'], columns = ['Outlet_Location_Type'],
# <ipython-input-43-cbbcc80c1005>:2: FutureWarning: The provided callable <function min at 0x7c3ce690e2a0> is currently using DataFrameGroupBy.min. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "min" instead.
#   pd.pivot_table(data_BM, index=[ 'Outlet_Size'], columns = ['Outlet_Location_Type'],
# <ipython-input-43-cbbcc80c1005>:2: FutureWarning: The provided callable <function max at 0x7c3ce690e160> is currently using DataFrameGroupBy.max. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "max" instead.
#   pd.pivot_table(data_BM, index=[ 'Outlet_Size'], columns = ['Outlet_Location_Type'],
#                              mean                               median  \
# Outlet_Location_Type       Tier 1       Tier 2       Tier 3     Tier 1
# Outlet_Size
# High                          NaN          NaN  2298.995256        NaN
# Medium                2348.354635          NaN  2847.959679  1966.1074
# Small                 1576.192909  2438.841866          NaN  1040.6454
#
#                                                  min                     \
# Outlet_Location_Type     Tier 2     Tier 3    Tier 1    Tier 2   Tier 3
# Outlet_Size
# High                        NaN  2050.6640       NaN       NaN  73.2380
# Medium                      NaN  2350.9398  111.8544       NaN  69.2432
# Small                 2109.2544        NaN   33.9558  113.8518      NaN
#
#                             max                                  sum  \
# Outlet_Location_Type     Tier 1     Tier 2      Tier 3        Tier 1
# Outlet_Size
# High                        NaN        NaN  10256.6490           NaN
# Medium                7646.0472        NaN  13086.9648  2.183970e+06
# Small                 9779.9362  8479.6288         NaN  2.298089e+06
#
#
# Outlet_Location_Type        Tier 2        Tier 3
# Outlet_Size
# High                           NaN  2.142664e+06
# Medium                         NaN  5.305749e+06
# Small                 2.268123e+06           NaN

# %%
# display top 5 products basis on the units_sold

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8523 entries, 0 to 8522
# Data columns (total 12 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Item_Identifier            8523 non-null   object
#  1   Item_Weight                7060 non-null   float64
#  2   Item_Fat_Content           8523 non-null   object
#  3   Item_Visibility            8523 non-null   float64
#  4   Item_Type                  8523 non-null   object
#  5   Item_MRP                   8523 non-null   float64
#  6   Outlet_Identifier          8523 non-null   object
#  7   Outlet_Establishment_Year  8523 non-null   int64
#  8   Outlet_Size                6113 non-null   object
#  9   Outlet_Location_Type       8523 non-null   object
#  10  Outlet_Type                8523 non-null   object
#  11  Item_Outlet_Sales          8523 non-null   float64
# dtypes: float64(4), int64(1), object(7)
# memory usage: 799.2+ KB

# %%
df['Item_MRP'] = df['Item_MRP'].astype(str)
df['Item_MRP'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 8523 entries, 0 to 8522
# Series name: Item_MRP
# Non-Null Count  Dtype
# --------------  -----
# 8523 non-null   object
# dtypes: object(1)
# memory usage: 66.7+ KB

# %%
df['Item_MRP'] = df['Item_MRP'].astype(float)

# %%
df['Item_MRP'].mean()
# Out:
# np.float64(140.9927819781767)

# %% [markdown]
# ### Data Export
#
# Suppose you are working on a Data Science project and you tackle one of the most important tasks, i.e, Data Cleaning. After data cleaning, you don’t want to lose your cleaned data frame, so you want to save your cleaned data frame as a CSV. Let us see how to export a Pandas DataFrame to a CSV file.
# Pandas enable us to do so with its inbuilt to_csv() function.
#
#     Syntax:
#
#     df.to_csv( self, path_or_buf=None, sep=",", na_rep="", float_format=None, columns=None, header=True, index=True,
#                 index_label=None, mode="w",encoding=None,compression="infer", quoting=None,quotechar='"',
#                 line_terminator=None,chunksize=None,date_format=None,doublequote=True,escapechar=None,decimal=".",
#               )
#
#     Parameters:
#     Some of the important parameters are:
#
#     path_or_buf: the file object to write the CSV data. If this argument is not provided, the CSV data is returned as a string.
#     sep: the delimiter for the CSV data. It should be a string of length 1, the default is a comma.
#     na_rep: string representing null or missing values, default is empty string.
#     columns: a sequence to specify the columns to include in the CSV output.
#     header: the allowed values are boolean or a list of string, default is True.
#             If False, the column names are not written in the output. If a list of string, it’s used to write
#             the column names. The length of the list of string should be the same as the number of columns being
#             written in the CSV file.
#     index: if True, index is included in the CSV data. If False, the index value is not written in the CSV output.
#     index_label: used to specify the column name for index.

# %%
avg_price_per_item = data_BM.groupby('Item_Type').Item_MRP.mean().reset_index()
avg_price_per_item
# Out:
#                 Item_Type    Item_MRP
# 0            Baking Goods  126.380766
# 1                  Breads  140.952669
# 2               Breakfast  141.788151
# 3                  Canned  139.763832
# 4                   Dairy  148.499208
# 5            Frozen Foods  138.503366
# 6   Fruits and Vegetables  144.581235
# 7             Hard Drinks  137.077928
# 8      Health and Hygiene  130.818921
# 9               Household  149.424753
# 10                   Meat  139.882032
# 11                 Others  132.851430
# 12                Seafood  141.841719
# 13            Snack Foods  146.194934
# 14            Soft Drinks  131.492506
# 15          Starchy Foods  147.838023

# %%
# Import
# CSV , XLSX
# pd.read_csv(path), pd.read_excel(path)


# Export
# csv   - df.to_csv('file_name.csv')
# Excel - df.to_excel('filename.xlsx')

avg_price_per_item.to_csv('avg_price_per_item_category.csv', index = False)

# %%
avg_price_per_item.to_excel('avg_price_per_item_category.xlsx', index = False)

# %%
avg_price_per_item.to_pickle('avg_price_per_item.pkl')

# %% [markdown]
# ### dataframe print without index
#
# When printing a dataframe, by default, index appears with the output but this can be removed if required. To print the dataframe without indices index parameter in to_string() must be set to False.

# %% [markdown]
# The End
#
# ---
