# %% [markdown]
# <a href="https://colab.research.google.com/github/Gokul7120/Python-/blob/main/sample_problem.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
np.random.seed(42)

Data = { 'Name': ['Ram','Som','Bom'],
        'Age':np.random.randint(25,35,size =3),
        'Salary': np.random.randint(20000,35000,size = 3),
         'Department': ['HR','IT','FINANCE'],
         'Join_Date': pd.date_range(start='2020-01-01',periods = 3 ,freq ='M'  ),
         'rating': np.random.randint(1,5,size =3)
         }
df = pd.DataFrame(Data)
df
# Out:
# <ipython-input-1-268a49077389>:9: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   'Join_Date': pd.date_range(start='2020-01-01',periods = 3 ,freq ='M'  ),
#   Name  Age  Salary Department  Join_Date  rating
# 0  Ram   31   31964         HR 2020-01-31       2
# 1  Som   28   31284         IT 2020-02-29       3
# 2  Bom   32   25734    FINANCE 2020-03-31       3

# %%
 import pandas as pd
 import numpy as np
 # Create a sample DataFrame
 np.random.seed(42)
 data = {
    'Name': ['Alice', 'Bob', 'Charlie', 'David', 'Eve', 'Frank','Grace', 'Hannah', 'Ivy', 'Jack'],
    'Age': np.random.randint(18, 60, size=10),
    'Gender': ['F', 'M', 'M', 'M', 'F', 'M', 'F', 'F', 'F', 'M'],
    'Salary': np.random.randint(30000, 100000, size=10),
    'Department': ['HR', 'IT', 'Finance', 'HR', 'Finance', 'IT', 'HR','Finance', 'IT', 'HR'],
    'Join_Date': pd.date_range(start='2020-01-01', periods=10,freq='M'),
    'Rating': np.random.uniform(1, 5, size=10).round(1)
 }
 df = pd.DataFrame(data)
 df
# Out:
# <ipython-input-2-385178cdf240>:11: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   'Join_Date': pd.date_range(start='2020-01-01', periods=10,freq='M'),
#       Name  Age Gender  Salary Department  Join_Date  Rating
# 0    Alice   56      F   74131         HR 2020-01-31     1.8
# 1      Bob   46      M   90263         IT 2020-02-29     1.7
# 2  Charlie   32      M   46023    Finance 2020-03-31     1.7
# 3    David   25      M   71090         HR 2020-04-30     2.2
# 4      Eve   38      F   97221    Finance 2020-05-31     3.1
# 5    Frank   56      M   94820         IT 2020-06-30     2.7
# 6    Grace   36      F   30769         HR 2020-07-31     2.2
# 7   Hannah   40      F   89735    Finance 2020-08-31     3.4
# 8      Ivy   28      F   92955         IT 2020-09-30     1.6
# 9     Jack   28      M   94925         HR 2020-10-31     2.2

# %%
 # Display the first 5 rows and then calculate the mean age of employees.
 df.head()
# Out:
#       Name  Age Gender  Salary Department  Join_Date  Rating
# 0    Alice   56      F   74131         HR 2020-01-31     1.8
# 1      Bob   46      M   90263         IT 2020-02-29     1.7
# 2  Charlie   32      M   46023    Finance 2020-03-31     1.7
# 3    David   25      M   71090         HR 2020-04-30     2.2
# 4      Eve   38      F   97221    Finance 2020-05-31     3.1

# %%
# : Show the total number of unique departments and display a summary of then DataFrame

df['Department'].nunique()
# Out:
# 3

# %%
df.describe()
# Out:
#             Age       Salary            Join_Date     Rating
# count  10.00000     10.00000                   10  10.000000
# mean   38.50000  78193.20000  2020-06-15 07:12:00   2.260000
# min    25.00000  30769.00000  2020-01-31 00:00:00   1.600000
# 25%    29.00000  71850.25000  2020-04-07 12:00:00   1.725000
# 50%    37.00000  89999.00000  2020-06-15 00:00:00   2.200000
# 75%    44.50000  94353.75000  2020-08-23 06:00:00   2.575000
# max    56.00000  97221.00000  2020-10-31 00:00:00   3.400000
# std    11.16791  23012.55255                  NaN   0.622183

# %%
#  Select employees whose rating is greater than 3 and show their names and salaries

df[df['Rating'] > 3][['Name', 'Salary']]
# Out:
#      Name  Salary
# 4     Eve   97221
# 7  Hannah   89735

# %%
df[df['Rating'] > 3]
# Out:
#      Name  Age Gender  Salary Department  Join_Date  Rating
# 4     Eve   38      F   97221    Finance 2020-05-31     3.1
# 7  Hannah   40      F   89735    Finance 2020-08-31     3.4

# %%
# Sort the DataFrame by salary in descending order, and display the top 3 records.
pd.set_option('display.max_rows', None)
df.sort_values(by='Salary', ascending=False).head(3)
# Out:
#     Name  Age Gender  Salary Department  Join_Date  Rating
# 4    Eve   38      F   97221    Finance 2020-05-31     3.1
# 9   Jack   28      M   94925         HR 2020-10-31     2.2
# 5  Frank   56      M   94820         IT 2020-06-30     2.7

# %%
 df.sort_values(by='Salary', ascending=False).nlargest(3, 'Salary')
# Out:
#     Name  Age Gender  Salary Department  Join_Date  Rating
# 4    Eve   38      F   97221    Finance 2020-05-31     3.1
# 9   Jack   28      M   94925         HR 2020-10-31     2.2
# 5  Frank   56      M   94820         IT 2020-06-30     2.7

# %%
#  Display all records where the employee works in the 'IT' or 'HR' department and has a salary above 50,000.

df[(df['Department'].isin([ 'IT','HR'])) &(  df['Salary'] > 50000)]
# Out:
#     Name  Age Gender  Salary Department  Join_Date  Rating
# 0  Alice   56      F   74131         HR 2020-01-31     1.8
# 1    Bob   46      M   90263         IT 2020-02-29     1.7
# 3  David   25      M   71090         HR 2020-04-30     2.2
# 5  Frank   56      M   94820         IT 2020-06-30     2.7
# 8    Ivy   28      F   92955         IT 2020-09-30     1.6
# 9   Jack   28      M   94925         HR 2020-10-31     2.2

# %%
# Filter the DataFrame to show employees with ratings greater than 3, and show the department-wise mean salary.

df[df['Rating'] > 3].groupby('Department')['Salary'].mean()
# Out:
# Department
# Finance    93478.0
# Name: Salary, dtype: float64

# %%
#  Show employees who joined after '2020-05-01' and display their age and department.

df[df['Join_Date'] > '2020-05-01'][['Age','Department']]
# Out:
#    Age Department
# 4   38    Finance
# 5   56         IT
# 6   36         HR
# 7   40    Finance
# 8   28         IT
# 9   28         HR

# %%
# Select rows where the employee's name starts with 'A' or 'B', and display their name, age, and salary
df[(df['Name'].str.startswith('A')) | (df['Name'].str.startswith('B'))][['Name', 'Age', 'Salary']]
# Out:
#     Name  Age  Salary
# 0  Alice   56   74131
# 1    Bob   46   90263

# %%
#  Create a new column 'Salary_in_Thousands' by dividing salary by 1000, and display the updated DataFrame.

df['Salary_in_thousands'] = df['Salary']/1000
df.head()
# Out:
#       Name  Age Gender  Salary Department  Join_Date  Rating  \
# 0    Alice   56      F   74131         HR 2020-01-31     1.8
# 1      Bob   46      M   90263         IT 2020-02-29     1.7
# 2  Charlie   32      M   46023    Finance 2020-03-31     1.7
# 3    David   25      M   71090         HR 2020-04-30     2.2
# 4      Eve   38      F   97221    Finance 2020-05-31     3.1
#
#    Salary_in_thousands
# 0               74.131
# 1               90.263
# 2               46.023
# 3               71.090
# 4               97.221

# %%
df.Salary_in_thousands = df.Salary_in_thousands.round(2)
df.head()
# Out:
#       Name  Age Gender  Salary Department  Join_Date  Rating  \
# 0    Alice   56      F   74131         HR 2020-01-31     1.8
# 1      Bob   46      M   90263         IT 2020-02-29     1.7
# 2  Charlie   32      M   46023    Finance 2020-03-31     1.7
# 3    David   25      M   71090         HR 2020-04-30     2.2
# 4      Eve   38      F   97221    Finance 2020-05-31     3.1
#
#    Salary_in_thousands
# 0                74.13
# 1                90.26
# 2                46.02
# 3                71.09
# 4                97.22

# %%
#  Remove the 'Rating' column and display the remaining columns.

df.drop(columns='Rating',inplace=True)
df.head()
# Out:
#       Name  Age Gender  Salary Department  Join_Date  Salary_in_thousands
# 0    Alice   56      F   74131         HR 2020-01-31               74.131
# 1      Bob   46      M   90263         IT 2020-02-29               90.263
# 2  Charlie   32      M   46023    Finance 2020-03-31               46.023
# 3    David   25      M   71090         HR 2020-04-30               71.090
# 4      Eve   38      F   97221    Finance 2020-05-31               97.221

# %%
# Filter employees with a rating greater than 3 and then display their names,salaries, and departments.
df[df['Rating'] > 3][['Name', 'Salary', 'Department']]
# Out:
#      Name  Salary Department
# 4     Eve   97221    Finance
# 7  Hannah   89735    Finance
# WARNING: Runtime no longer has a reference to this dataframe, please re-run this cell and try again.

# %%
#  Display the number of employees in each department, and calculate the mean age of employees.

df.groupby('Department').value_counts(), df['Age'].mean()
# Out:
# (Department  Name     Age  Gender  Salary  Join_Date   Rating
#  Finance     Charlie  32   M       46023   2020-03-31  1.7       1
#              Eve      38   F       97221   2020-05-31  3.1       1
#              Hannah   40   F       89735   2020-08-31  3.4       1
#  HR          Alice    56   F       74131   2020-01-31  1.8       1
#              David    25   M       71090   2020-04-30  2.2       1
#              Grace    36   F       30769   2020-07-31  2.2       1
#              Jack     28   M       94925   2020-10-31  2.2       1
#  IT          Bob      46   M       90263   2020-02-29  1.7       1
#              Frank    56   M       94820   2020-06-30  2.7       1
#              Ivy      28   F       92955   2020-09-30  1.6       1
#  Name: count, dtype: int64,
#  np.float64(38.5))

# %%
# Sort employees by 'Join_Date' in ascending order and display the top 5 rows

df.sort_values(by='Join_Date', ascending=True).head()
# Out:
#       Name  Age Gender  Salary Department  Join_Date  Rating
# 0    Alice   56      F   74131         HR 2020-01-31     1.8
# 1      Bob   46      M   90263         IT 2020-02-29     1.7
# 2  Charlie   32      M   46023    Finance 2020-03-31     1.7
# 3    David   25      M   71090         HR 2020-04-30     2.2
# 4      Eve   38      F   97221    Finance 2020-05-31     3.1

# %%
# Select employees with a salary higher than 60,000 and who joined after January 2020, displaying their names and ages
df[(df['Salary'] > 60000) & ( df['Join_Date'] > '2020-01-01')][['Name', 'Age']]
# Out:
#      Name  Age
# 0   Alice   56
# 1     Bob   46
# 3   David   25
# 4     Eve   38
# 5   Frank   56
# 7  Hannah   40
# 8     Ivy   28
# 9    Jack   28

# %%
#  Create a new column 'Age_Group' that labels employees as 'Young' if their age is below 30, otherwise 'Experienced'.
# Then display the first 5 rows
df['Age_Group'] = np.where(df['Age'] < 30, 'Young', 'Experienced')
df.head()
# Out:
#       Name  Age Gender  Salary Department  Join_Date  Rating    Age_Group
# 0    Alice   56      F   74131         HR 2020-01-31     1.8  Experienced
# 1      Bob   46      M   90263         IT 2020-02-29     1.7  Experienced
# 2  Charlie   32      M   46023    Finance 2020-03-31     1.7  Experienced
# 3    David   25      M   71090         HR 2020-04-30     2.2        Young
# 4      Eve   38      F   97221    Finance 2020-05-31     3.1  Experienced

# %%
df['Age_Group'] = df['Age'].apply(lambda x: 'Young' if x<30 else
'Experienced')
df
# Out:
#       Name  Age Gender  Salary Department  Join_Date  Rating    Age_Group
# 0    Alice   56      F   74131         HR 2020-01-31     1.8  Experienced
# 1      Bob   46      M   90263         IT 2020-02-29     1.7  Experienced
# 2  Charlie   32      M   46023    Finance 2020-03-31     1.7  Experienced
# 3    David   25      M   71090         HR 2020-04-30     2.2        Young
# 4      Eve   38      F   97221    Finance 2020-05-31     3.1  Experienced
# 5    Frank   56      M   94820         IT 2020-06-30     2.7  Experienced
# 6    Grace   36      F   30769         HR 2020-07-31     2.2  Experienced
# 7   Hannah   40      F   89735    Finance 2020-08-31     3.4  Experienced
# 8      Ivy   28      F   92955         IT 2020-09-30     1.6        Young
# 9     Jack   28      M   94925         HR 2020-10-31     2.2        Young

# %%
#  Filter employees in the 'HR' department and calculate the mean and standard deviation of their salaries
df[df['Department']=='HR'][['Salary']].mean(),df[df['Department']=='HR'][['Salary']].std()
# Out:
# (Salary    67728.75
#  dtype: float64,
#  Salary    26820.054317
#  dtype: float64)

# %%
df[df['Department']=='HR'][['Salary']].mean()[['Salary']].std()
# Out:
# nan

# %%
 df[df['Department'] == 'HR']['Salary'].agg(['mean', 'std'])
# Out:
# mean    67728.750000
# std     26820.054317
# Name: Salary, dtype: float64

# %%
df[df['Department'] == 'HR']['Salary'].describe()[['mean', 'std']]
# Out:
# mean    67728.750000
# std     26820.054317
# Name: Salary, dtype: float64

# %%
df.groupby('Department')['Salary'].agg(['mean', 'std']).loc['HR']
# Out:
# mean    67728.750000
# std     26820.054317
# Name: HR, dtype: float64

# %%
hr_salaries = df[df['Department'] == 'HR']['Salary']
mean_val = hr_salaries.mean()
std_val = hr_salaries.std()

print(f"Mean: {mean_val}, Std: {std_val}")
# Out:
# Mean: 67728.75, Std: 26820.054317307662

# %%
#  Display employees whose name ends with the letter 'e' and whose rating is exactly 3.1

df[(df['Name'].str.endswith('e')) & (df['Rating'] == 3.1)]
# Out:
#   Name  Age Gender  Salary Department  Join_Date  Rating
# 4  Eve   38      F   97221    Finance 2020-05-31     3.1

# %%
#  Find the median salary and count of employees for each gender
df.groupby('Gender')['Salary'].agg(['median', 'count'])
# Out:
#          median  count
# Gender
# F       89735.0      5
# M       90263.0      5

# %%
#  Filter employees whose salary is within 40,000 to 70,000, and then display their names and departments
df[(df['Salary'] >= 40000) & (df['Salary'] <= 70000)][['Name', 'Department']]
# Out:
#       Name Department
# 2  Charlie    Finance

# %%
df[df['Salary'].between(40000, 70000)][['Name', 'Department']]
# Out:
#       Name Department
# 2  Charlie    Finance

# %%
#  For employees older than 35, display their names, departments, and the difference between their salary and the average salary
df[df['Age'] > 35][['Name', 'Department', 'Salary']].assign(avg_salary=df['Salary']-df['Salary'].mean())
# Out:
#      Name Department  Salary  avg_salary
# 0   Alice         HR   74131     -4062.2
# 1     Bob         IT   90263     12069.8
# 4     Eve    Finance   97221     19027.8
# 5   Frank         IT   94820     16626.8
# 6   Grace         HR   30769    -47424.2
# 7  Hannah    Finance   89735     11541.8

# %%
 df['Salary_Avg_Salary_Diff'] = df['Salary'] - df['Salary'].mean()
 df[df['Age'] > 35][['Name', 'Department','Salary_Avg_Salary_Diff']]
# Out:
#      Name Department  Salary_Avg_Salary_Diff
# 0   Alice         HR                 -4062.2
# 1     Bob         IT                 12069.8
# 4     Eve    Finance                 19027.8
# 5   Frank         IT                 16626.8
# 6   Grace         HR                -47424.2
# 7  Hannah    Finance                 11541.8

# %%
#  Filter employees with a salary greater than 50,000 and display their names and departments.
# Then sort the results by 'Rating' in descending order.
df[df['Salary'] > 50000][['Name', 'Department','Rating']].sort_values(by='Rating', ascending=False)
# Out:
#      Name Department  Rating
# 7  Hannah    Finance     3.4
# 4     Eve    Finance     3.1
# 5   Frank         IT     2.7
# 3   David         HR     2.2
# 9    Jack         HR     2.2
# 0   Alice         HR     1.8
# 1     Bob         IT     1.7
# 8     Ivy         IT     1.6

# %%
# : Count the number of employees in each department, and then filter departments with more than 3 employees
df.groupby('Department').value_counts()
# Out:
# Department  Name     Age  Gender  Salary  Join_Date   Rating  Salary_Avg_Salary_Diff
# Finance     Charlie  32   M       46023   2020-03-31  1.7     -32170.2                  1
#             Eve      38   F       97221   2020-05-31  3.1      19027.8                  1
#             Hannah   40   F       89735   2020-08-31  3.4      11541.8                  1
# HR          Alice    56   F       74131   2020-01-31  1.8     -4062.2                   1
#             David    25   M       71090   2020-04-30  2.2     -7103.2                   1
#             Grace    36   F       30769   2020-07-31  2.2     -47424.2                  1
#             Jack     28   M       94925   2020-10-31  2.2      16731.8                  1
# IT          Bob      46   M       90263   2020-02-29  1.7      12069.8                  1
#             Frank    56   M       94820   2020-06-30  2.7      16626.8                  1
# ...

# %%
df.groupby('Department').agg({'Name': 'count'}).loc[lambda x: x['Name'] > 3]
# Out:
#             Name
# Department
# HR             4

# %%
# Create a new column 'Salary_After_Tax' by reducing 15% tax from the salary and
# then display the first 5 rows with 'Name' and 'Salary_After_Tax'.

df['Salary_After_Tax'] = df['Salary'] * 0.85
df[['Name', 'Salary_After_Tax']].head()
# Out:
#       Name  Salary_After_Tax
# 0    Alice          63011.35
# 1      Bob          76723.55
# 2  Charlie          39119.55
# 3    David          60426.50
# 4      Eve          82637.85

# %%
# : Filter employees in the 'Finance' department and calculate the mean age and median salary for these employees.

df[df['Department'] == 'Finance'][['Age','Salary']].agg(['mean', 'median']).round(2)
# Out:
#           Age    Salary
# mean    36.67  77659.67
# median  38.00  89735.00

# %%
#  Select employees whose names contain the letter 'A' and who are older than 30, displaying their names and ages.


df[df['Name'].str.contains('A') & (df['Age'] > 30)][['Name','Age']]
# Out:
#     Name  Age
# 0  Alice   56

# %%
# Calculate the sum of salaries and count of employees in each department.

df.groupby('Department').agg({'Salary': 'sum', 'Name': 'count'})
# Out:
#             Salary  Name
# Department
# Finance     232979     3
# HR          270915     4
# IT          278038     3

# %%
#  Sort employees by 'Salary' in descending order and then display the top 3 employees along with their names and ratings

df.sort_values(by='Salary', ascending=False).head(3)[['Name', 'Rating']]
# Out:
#     Name  Rating
# 4    Eve     3.1
# 9   Jack     2.2
# 5  Frank     2.7

# %%
# Filter employees who have a rating below the median rating and display their names and departments.

median_rating = df['Rating'].median()
df[df['Rating'] < median_rating][['Name', 'Department']]
# Out:
#       Name Department
# 0    Alice         HR
# 1      Bob         IT
# 2  Charlie    Finance
# 8      Ivy         IT

# %%
#  Create a new column 'Experience_Level' to classify employees with less than 2 years of experience as
# 'Junior', otherwise 'Senior'. Then display the first 5 rows

df['Experience_Level'] = np.where(df['Join_Date'].dt.year <= 2020, 'Junior', 'Senior')
df.head()
# Out:
#       Name  Age Gender  Salary Department  Join_Date  Rating  \
# 0    Alice   56      F   74131         HR 2020-01-31     1.8
# 1      Bob   46      M   90263         IT 2020-02-29     1.7
# 2  Charlie   32      M   46023    Finance 2020-03-31     1.7
# 3    David   25      M   71090         HR 2020-04-30     2.2
# 4      Eve   38      F   97221    Finance 2020-05-31     3.1
#
#    Salary_Avg_Salary_Diff  Salary_After_Tax Experience_Level
# 0                 -4062.2          63011.35           Junior
# 1                 12069.8          76723.55           Junior
# 2                -32170.2          39119.55           Junior
# 3                 -7103.2          60426.50           Junior
# 4                 19027.8          82637.85           Junior

# %%
df['Experience'] = (pd.Timestamp.now() - df['Join_Date']).dt.days // 365
df['Experience_Level'] = df['Experience'].apply(lambda x: 'Junior' if
x < 2 else 'Senior')
df.head()
# Out:
#       Name  Age Gender  Salary Department  Join_Date  Rating  \
# 0    Alice   56      F   74131         HR 2020-01-31     1.8
# 1      Bob   46      M   90263         IT 2020-02-29     1.7
# 2  Charlie   32      M   46023    Finance 2020-03-31     1.7
# 3    David   25      M   71090         HR 2020-04-30     2.2
# 4      Eve   38      F   97221    Finance 2020-05-31     3.1
#
#    Salary_Avg_Salary_Diff  Salary_After_Tax Experience_Level  Experience
# 0                 -4062.2          63011.35           Senior           5
# 1                 12069.8          76723.55           Senior           5
# 2                -32170.2          39119.55           Senior           5
# 3                 -7103.2          60426.50           Senior           4
# 4                 19027.8          82637.85           Senior           4

# %%
# : For employees in the 'HR' department, display their names and calculate the
# difference between their salary and the department's average salary

hr_avg_salary = df[df['Department'] == 'HR']['Salary'].mean()
df[df['Department'] == 'HR'][['Name', 'Salary']].assign(diff_from_avg=lambda x: x['Salary'] - hr_avg_salary)
# Out:
#     Name  Salary  diff_from_avg
# 0  Alice   74131        6402.25
# 3  David   71090        3361.25
# 6  Grace   30769      -36959.75
# 9   Jack   94925       27196.25

# %%
#  Filter employees who joined after the year 2019, then display their names and salaries, sorted by 'Salary' in descending order.


df[df['Join_Date'] >= '2019-01-01'][['Name', 'Salary',]].sort_values(by='Salary', ascending=False)
# Out:
#       Name  Salary
# 4      Eve   97221
# 9     Jack   94925
# 5    Frank   94820
# 8      Ivy   92955
# 1      Bob   90263
# 7   Hannah   89735
# 0    Alice   74131
# 3    David   71090
# 2  Charlie   46023
# 6    Grace   30769

# %%
#  Select employees with salaries greater than 60,000 and whose names contain the letter 'e', and display their names and departments.

df[(df['Salary'] > 60000) & (df['Name'].str.contains('e'))][['Name', 'Department']]
# Out:
#     Name Department
# 0  Alice         HR
# 4    Eve    Finance

# %%
# : Create a new column 'Years_In_Company' by subtracting 'Join_Date' from today's date, then display the first 5 rows with this column.

df['Years_In_Company'] = (pd.Timestamp.now() - df['Join_Date']).dt.days // 365
df.head()
# Out:
#       Name  Age Gender  Salary Department  Join_Date  Rating  \
# 0    Alice   56      F   74131         HR 2020-01-31     1.8
# 1      Bob   46      M   90263         IT 2020-02-29     1.7
# 2  Charlie   32      M   46023    Finance 2020-03-31     1.7
# 3    David   25      M   71090         HR 2020-04-30     2.2
# 4      Eve   38      F   97221    Finance 2020-05-31     3.1
#
#    Salary_Avg_Salary_Diff  Salary_After_Tax Experience_Level  Experience  \
# 0                 -4062.2          63011.35           Senior           5
# 1                 12069.8          76723.55           Senior           5
# 2                -32170.2          39119.55           Senior           5
# 3                 -7103.2          60426.50           Senior           4
# 4                 19027.8          82637.85           Senior           4
#
#    Years_In_Company
# 0                 5
# 1                 5
# 2                 5
# 3                 4
# 4                 4

# %%
#  Group employees by 'Department' and calculate the mean and median salaries.
# Then display departments with a mean salary greater than 55,000.
df.groupby('Department')['Salary'].agg(['mean', 'median']).loc[lambda x: x['mean'] > 55000]
# Out:
#                     mean   median
# Department
# Finance     77659.666667  89735.0
# HR          67728.750000  72610.5
# IT          92679.333333  92955.0

# %%
#  Filter employees in the 'HR' department and calculate the average rating and total salary of these employees.
df[df['Department'] == 'HR'].agg({'Rating':'mean', 'Salary':'sum'})
# Out:
# Rating         2.1
# Salary    270915.0
# dtype: float64

# %%
#  Create a column 'Salary_Tax' by applying a 20% tax deduction on salaries, then
# filter employees with a net salary greater than 50,000.
df['Salary_Tax'] = df['Salary'] * 0.8
df[df['Salary_Tax'] > 50000]
# Out:
#      Name  Age Gender  Salary Department  Join_Date  Rating  Salary_Tax
# 0   Alice   56      F   74131         HR 2020-01-31     1.8     59304.8
# 1     Bob   46      M   90263         IT 2020-02-29     1.7     72210.4
# 3   David   25      M   71090         HR 2020-04-30     2.2     56872.0
# 4     Eve   38      F   97221    Finance 2020-05-31     3.1     77776.8
# 5   Frank   56      M   94820         IT 2020-06-30     2.7     75856.0
# 7  Hannah   40      F   89735    Finance 2020-08-31     3.4     71788.0
# 8     Ivy   28      F   92955         IT 2020-09-30     1.6     74364.0
# 9    Jack   28      M   94925         HR 2020-10-31     2.2     75940.0

# %%
#  Count the number of employees in each department and display only the departments with more than 3 employees
df.groupby('Department').agg({'Name': 'count'}).loc[lambda x: x['Name'] > 3]
# Out:
#             Name
# Department
# HR             4

# %%
df['Total_Dept_Employees'] = df.groupby('Department').agg('Name').transform('count')
df[df['Total_Dept_Employees'] > 3]
# Out:
#     Name  Age Gender  Salary Department  Join_Date  Rating  Salary_Tax  \
# 0  Alice   56      F   74131         HR 2020-01-31     1.8     59304.8
# 3  David   25      M   71090         HR 2020-04-30     2.2     56872.0
# 6  Grace   36      F   30769         HR 2020-07-31     2.2     24615.2
# 9   Jack   28      M   94925         HR 2020-10-31     2.2     75940.0
#
#    Total_Dept_Employees
# 0                     4
# 3                     4
# 6                     4
# 9                     4

# %%
#  Select employees who are older than 35 and have a rating greater than 3.0, then display their names and ratings.

df[(df['Age'] > 35) & (df['Rating'] > 3.0)] [['Name','Rating']]
# Out:
#      Name  Rating
# 4     Eve     3.1
# 7  Hannah     3.4

# %%
#  Calculate the sum of salaries for each department and sort the results in ascending order of total salary.
df.groupby('Department')['Salary'].transform('sum')
# Out:
# 0    270915
# 1    278038
# 2    232979
# 3    270915
# 4    232979
# 5    278038
# 6    270915
# 7    232979
# 8    278038
# 9    270915
# Name: Salary, dtype: int64

# %%
 df['Dept_Total_Salary'] = df.groupby('Department') ['Salary'].transform('sum')
 df.sort_values(by='Dept_Total_Salary')
# Out:
#       Name  Age Gender  Salary Department  Join_Date  Rating  Salary_Tax  \
# 2  Charlie   32      M   46023    Finance 2020-03-31     1.7     36818.4
# 4      Eve   38      F   97221    Finance 2020-05-31     3.1     77776.8
# 7   Hannah   40      F   89735    Finance 2020-08-31     3.4     71788.0
# 0    Alice   56      F   74131         HR 2020-01-31     1.8     59304.8
# 6    Grace   36      F   30769         HR 2020-07-31     2.2     24615.2
# 3    David   25      M   71090         HR 2020-04-30     2.2     56872.0
# 9     Jack   28      M   94925         HR 2020-10-31     2.2     75940.0
# 1      Bob   46      M   90263         IT 2020-02-29     1.7     72210.4
# 5    Frank   56      M   94820         IT 2020-06-30     2.7     75856.0
# 8      Ivy   28      F   92955         IT 2020-09-30     1.6     74364.0
#
#    Total_Dept_Employees  Total_Salary  Dept_Total_Salary
# 2                     3        232979             232979
# ...

# %%
#  Create a column 'Salary_Diff' that calculates the difference between an employee's salary and
#the mean salary of their department. Then display the first 5 rows.

df['Salary_Diff'] =df.groupby('Department')['Salary'].transform(lambda x: x - x.mean())
df.head()
# Out:
#       Name  Age Gender  Salary Department  Join_Date  Rating  Salary_Tax  \
# 0    Alice   56      F   74131         HR 2020-01-31     1.8     59304.8
# 1      Bob   46      M   90263         IT 2020-02-29     1.7     72210.4
# 2  Charlie   32      M   46023    Finance 2020-03-31     1.7     36818.4
# 3    David   25      M   71090         HR 2020-04-30     2.2     56872.0
# 4      Eve   38      F   97221    Finance 2020-05-31     3.1     77776.8
#
#    Total_Dept_Employees  Total_Salary  Dept_Total_Salary   Salary_Diff
# 0                     4        270915             270915   6402.250000
# 1                     3        278038             278038  -2416.333333
# 2                     3        232979             232979 -31636.666667
# 3                     4        270915             270915   3361.250000
# 4                     3        232979             232979  19561.333333

# %%
 #Intermediate Questions
 #  Group employees by department, and find the maximum salary and minimum age for each department.

 df.groupby('Department').agg({'Salary': 'max','Age' : 'min'})
# Out:
#             Salary  Age
# Department
# Finance      97221   32
# HR           94925   25
# IT           94820   28

# %%
# Display the first 5 records where employees are male, and their age is less than 40
df[(df['Gender'] == 'M') & (df['Age'] < 40)].head()
# Out:
#       Name  Age Gender  Salary Department  Join_Date  Rating  Salary_Tax  \
# 2  Charlie   32      M   46023    Finance 2020-03-31     1.7     36818.4
# 3    David   25      M   71090         HR 2020-04-30     2.2     56872.0
# 9     Jack   28      M   94925         HR 2020-10-31     2.2     75940.0
#
#    Total_Dept_Employees  Total_Salary  Dept_Total_Salary   Salary_Diff
# 2                     3        232979             232979 -31636.666667
# 3                     4        270915             270915   3361.250000
# 9                     4        270915             270915  27196.250000

# %%
#  Create a new column 'Experience' as the difference between the current date
# and their join date, and show the first 5 rows

df['Experience'] = (pd.Timestamp.now()- df['Join_Date']) .dt.days //365
df['Experience']
# Out:
# 0    5
# 1    5
# 2    5
# 3    4
# 4    4
# 5    4
# 6    4
# 7    4
# 8    4
# 9    4
# Name: Experience, dtype: int64

# %%
 # Find the total number of female employees and the average rating of male employees.

 df[df['Gender'] == 'F']['Name'].count(), df[df['Gender'] == 'M']['Rating'].mean()
# Out:
# (np.int64(5), np.float64(2.1))

# %%
 df[df['Gender'] == 'F'].shape[0], df[df['Gender'] == 'M']['Rating'].mean()
# Out:
# (5, np.float64(2.1))

# %%
#  For employees in the 'Finance' department, calculate the mean age and the total salary.

df[df['Department'] == 'Finance'][['Age','Salary']].agg(['mean', 'sum'])
# Out:
#              Age         Salary
# mean   36.666667   77659.666667
# sum   110.000000  232979.000000

# %%
#  Sort employees by age, then reset the index of the sorted DataFrame.

df.sort_values(by = 'Age').reset_index(drop=True)
# Out:
#       Name  Age Gender  Salary Department  Join_Date  Rating  Salary_Tax  \
# 0    David   25      M   71090         HR 2020-04-30     2.2     56872.0
# 1      Ivy   28      F   92955         IT 2020-09-30     1.6     74364.0
# 2     Jack   28      M   94925         HR 2020-10-31     2.2     75940.0
# 3  Charlie   32      M   46023    Finance 2020-03-31     1.7     36818.4
# 4    Grace   36      F   30769         HR 2020-07-31     2.2     24615.2
# 5      Eve   38      F   97221    Finance 2020-05-31     3.1     77776.8
# 6   Hannah   40      F   89735    Finance 2020-08-31     3.4     71788.0
# 7      Bob   46      M   90263         IT 2020-02-29     1.7     72210.4
# 8    Frank   56      M   94820         IT 2020-06-30     2.7     75856.0
# 9    Alice   56      F   74131         HR 2020-01-31     1.8     59304.8
#
#    Total_Dept_Employees  Total_Salary  Dept_Total_Salary   Salary_Diff  \
# 0                     4        270915             270915   3361.250000
# ...

# %%
# Filter employees with a salary in the range 40,000 to 90,000, and display their department and rating.

df[(df['Salary'] >= 40000) & (df['Salary'] <= 90000)][['Department','Rating']]
# Out:
#   Department  Rating
# 0         HR     1.8
# 2    Finance     1.7
# 3         HR     2.2
# 7    Finance     3.4

# %%
# Find the median salary for each gender and department combination

df.groupby(['Gender', 'Department'])['Salary'].median()
# Out:
# Gender  Department
# F       Finance       93478.0
#         HR            52450.0
#         IT            92955.0
# M       Finance       46023.0
#         HR            83007.5
#         IT            92541.5
# Name: Salary, dtype: float64

# %%
#  Filter employees who joined before 2021 and whose salary is above the average salary.

df[df['Join_Date'] < '2021-01-01'][df['Salary'] > df['Salary'].mean()]
# Out:
#      Name  Age Gender  Salary Department  Join_Date  Rating  Salary_Tax  \
# 1     Bob   46      M   90263         IT 2020-02-29     1.7     72210.4
# 4     Eve   38      F   97221    Finance 2020-05-31     3.1     77776.8
# 5   Frank   56      M   94820         IT 2020-06-30     2.7     75856.0
# 7  Hannah   40      F   89735    Finance 2020-08-31     3.4     71788.0
# 8     Ivy   28      F   92955         IT 2020-09-30     1.6     74364.0
# 9    Jack   28      M   94925         HR 2020-10-31     2.2     75940.0
#
#    Total_Dept_Employees  Total_Salary  Dept_Total_Salary   Salary_Diff  \
# 1                     3        278038             278038  -2416.333333
# 4                     3        232979             232979  19561.333333
# 5                     3        278038             278038   2140.666667
# 7                     3        232979             232979  12075.333333
# 8                     3        278038             278038    275.666667
# ...

# %%
#  For each department, find the count of employees and the average salary. Sort by average salary in descending order.

df.groupby('Department').agg({'Name': 'count', 'Salary': 'mean'}).sort_values(by='Salary', ascending=False)
# Out:
#             Name        Salary
# Department
# IT             3  92679.333333
# Finance        3  77659.666667
# HR             4  67728.750000

# %%
 # Group employees by gender and department, then calculate the average rating and total salary for each group

 df.groupby(['Gender', 'Department']).agg({'Rating': 'mean', 'Salary': 'sum'})
# Out:
#                    Rating  Salary
# Gender Department
# F      Finance       3.25  186956
#        HR            2.00  104900
#        IT            1.60   92955
# M      Finance       1.70   46023
#        HR            2.20  166015
#        IT            2.20  185083

# %%
#  Filter employees with a rating above the overall average rating and sort them by salary in descending order

df[df['Rating'] > df['Rating'].mean()].sort_values(by='Salary', ascending=False)
# Out:
#      Name  Age Gender  Salary Department  Join_Date  Rating  Salary_Tax  \
# 4     Eve   38      F   97221    Finance 2020-05-31     3.1     77776.8
# 5   Frank   56      M   94820         IT 2020-06-30     2.7     75856.0
# 7  Hannah   40      F   89735    Finance 2020-08-31     3.4     71788.0
#
#    Total_Dept_Employees  Total_Salary  Dept_Total_Salary   Salary_Diff  \
# 4                     3        232979             232979  19561.333333
# 5                     3        278038             278038   2140.666667
# 7                     3        232979             232979  12075.333333
#
#    Experience
# 4           4
# 5           4
# 7           4
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['Age'].plot(kind='hist', bins=20, title='Age')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# ...

# %%
#  Create a new column 'Years_Since_Joining' that calculates the number of years since an employee joined, and display the first 5 rows.

df['Years_Since_Joining'] = (pd.Timestamp.now() - df['Join_Date']).dt.days // 365
df.head()
# Out:
#       Name  Age Gender  Salary Department  Join_Date  Rating  Salary_Tax  \
# 0    Alice   56      F   74131         HR 2020-01-31     1.8     59304.8
# 1      Bob   46      M   90263         IT 2020-02-29     1.7     72210.4
# 2  Charlie   32      M   46023    Finance 2020-03-31     1.7     36818.4
# 3    David   25      M   71090         HR 2020-04-30     2.2     56872.0
# 4      Eve   38      F   97221    Finance 2020-05-31     3.1     77776.8
#
#    Total_Dept_Employees  Total_Salary  Dept_Total_Salary   Salary_Diff  \
# 0                     4        270915             270915   6402.250000
# 1                     3        278038             278038  -2416.333333
# 2                     3        232979             232979 -31636.666667
# 3                     4        270915             270915   3361.250000
# 4                     3        232979             232979  19561.333333
#
#    Experience  Years_Since_Joining
# 0           5                    5
# ...

# %%
#  Display employees with a salary in the top 10%, showing their name, salary, and department.

df[df['Salary'] >= df['Salary'].quantile(0.9)] [['Name','Salary','Department']]
# Out:
#   Name  Salary Department
# 4  Eve   97221    Finance

# %%
# : Calculate the average rating of employees for each combination of department and gender, and
# filter those with an average rating above 2
df.groupby(['Gender', 'Department']) ['Rating'].mean().reset_index().query('Rating > 2')
# Out:
#   Gender Department  Rating
# 0      F    Finance    3.25
# 4      M         HR    2.20
# 5      M         IT    2.20

# %%
# For each department, calculate the sum of salaries and the count of employees,   and filter departments with more than 3 employees

df.groupby('Department').agg({'Salary': 'sum', 'Name': 'count'}).loc[lambda x: x['Name'] > 3]
# Out:
#             Salary  Name
# Department
# HR          270915     4

# %%
#  Find the youngest and oldest employees in each department and display their names, age, and department.
df.groupby('Department').agg({'Age': ['max','min']})
# Out:
#            Age
#            max min
# Department
# Finance     40  32
# HR          56  25
# IT          56  28

# %%
youngest = df.loc[df.groupby('Department')['Age'].idxmin() ][['Name', 'Age', 'Department']]
oldest   = df.loc[df.groupby('Department')['Age'].idxmax()][['Name', 'Age', 'Department']]

result = pd.concat([youngest, oldest]).sort_values(['Department', 'Age'])
result
# Out:
#       Name  Age Department
# 2  Charlie   32    Finance
# 7   Hannah   40    Finance
# 3    David   25         HR
# 0    Alice   56         HR
# 8      Ivy   28         IT
# 5    Frank   56         IT

# %%
# Display the names and salaries of employees whose salary is more than the average salary of their respective department.

df[df['Salary'] > df.groupby('Department')['Salary'].transform('mean')][['Name', 'Salary']]
# Out:
#      Name  Salary
# 0   Alice   74131
# 3   David   71090
# 4     Eve   97221
# 5   Frank   94820
# 7  Hannah   89735
# 8     Ivy   92955
# 9    Jack   94925

# %%
df['Dept_Avg_Salary'] = df.groupby('Department') ['Salary'].transform('mean')
df[df['Salary'] > df['Dept_Avg_Salary']][['Name', 'Salary','Dept_Avg_Salary']]
# Out:
#      Name  Salary  Dept_Avg_Salary
# 0   Alice   74131     67728.750000
# 3   David   71090     67728.750000
# 4     Eve   97221     77659.666667
# 5   Frank   94820     92679.333333
# 7  Hannah   89735     77659.666667
# 8     Ivy   92955     92679.333333
# 9    Jack   94925     67728.750000

# %%
#  Create a new column 'Salary_Per_Year_Of_Experience' by dividing the salary by
#the number of years since joining, and then filter employees with a salary per year greater than 15,000.


df['Years_Since_Joining'] = (pd.Timestamp.now() - df['Join_Date']).dt.days // 365

df['Salary_Per_Year_Of_Experience'] = df['Salary'] / df['Years_Since_Joining']

df[df['Salary_Per_Year_Of_Experience'] > 15000]
# Out:
#      Name  Age Gender  Salary Department  Join_Date  Rating  Dept_Avg_Salary  \
# 1     Bob   46      M   90263         IT 2020-02-29     1.7     92679.333333
# 3   David   25      M   71090         HR 2020-04-30     2.2     67728.750000
# 4     Eve   38      F   97221    Finance 2020-05-31     3.1     77659.666667
# 5   Frank   56      M   94820         IT 2020-06-30     2.7     92679.333333
# 7  Hannah   40      F   89735    Finance 2020-08-31     3.4     77659.666667
# 8     Ivy   28      F   92955         IT 2020-09-30     1.6     92679.333333
# 9    Jack   28      M   94925         HR 2020-10-31     2.2     67728.750000
#
#    Years_Since_Joining  Salary_Per_Year_Of_Experience
# 1                    5                       18052.60
# 3                    4                       17772.50
# 4                    4                       24305.25
# 5                    4                       23705.00
# 7                    4                       22433.75
# ...

# %%
# Find employees who have been in the company for more than 3 years and whose salary is below the median salary of their department

df['Years_In_Company'] = (pd.Timestamp.now() - df['Join_Date']).dt.days // 365

df[df['Years_In_Company'] > 3][df['Salary'] < df.groupby('Department')['Salary'].transform('median')]
# Out:
#       Name  Age Gender  Salary Department  Join_Date  Rating  Dept_Avg_Salary  \
# 1      Bob   46      M   90263         IT 2020-02-29     1.7     92679.333333
# 2  Charlie   32      M   46023    Finance 2020-03-31     1.7     77659.666667
# 3    David   25      M   71090         HR 2020-04-30     2.2     67728.750000
# 6    Grace   36      F   30769         HR 2020-07-31     2.2     67728.750000
#
#    Years_Since_Joining  Salary_Per_Year_Of_Experience  Years_In_Company
# 1                    5                       18052.60                 5
# 2                    5                        9204.60                 5
# 3                    4                       17772.50                 4
# 6                    4                        7692.25                 4

# %%
#  Group employees by gender and department, calculate the average salary and
# the count of employees in each group, and filter groups with an average salary above 60,000.

df.groupby(['Gender', 'Department']).agg({'Salary': 'mean', 'Name': 'count'}).loc[lambda x: x['Salary'] > 60000]
# Out:
#                     Salary  Name
# Gender Department
# F      Finance     93478.0     2
#        IT          92955.0     1
# M      HR          83007.5     2
#        IT          92541.5     2

# %%
# Create a new column 'Years_Till_Retirement' that calculates how many years remain until the employee reaches 65 years of age.
# Then filter employees who will retire in less than 10 years.
df['Years_Till_Retirement'] = 65 - df['Age']
df[df['Years_Till_Retirement'] < 10]
# Out:
#     Name  Age Gender  Salary Department  Join_Date  Rating  Dept_Avg_Salary  \
# 0  Alice   56      F   74131         HR 2020-01-31     1.8     67728.750000
# 5  Frank   56      M   94820         IT 2020-06-30     2.7     92679.333333
#
#    Years_Since_Joining  Salary_Per_Year_Of_Experience  Years_In_Company  \
# 0                    5                        14826.2                 5
# 5                    4                        23705.0                 4
#
#    Years_Till_Retirement
# 0                      9
# 5                      9

# %%
#  Sort employees by 'Join_Date' and calculate the cumulative sum of salaries within each department
df.sort_values(by = 'Join_Date').groupby('Department')['Salary'].cumsum()
# Out:
# 0     74131
# 1     90263
# 2     46023
# 3    145221
# 4    143244
# 5    185083
# 6    175990
# 7    232979
# 8    278038
# 9    270915
# Name: Salary, dtype: int64

# %%
# Display employees with the top 5 highest ratings, showing their names,
# salaries, and the difference between their salary and the overall average salary.


df['Salary_Avg_Salary_Diff'] = df['Salary'] - df['Salary'].mean()

df.nlargest(5, 'Rating' )[['Name', 'Salary', 'Salary_Avg_Salary_Diff']]
# Out:
#      Name  Salary  Salary_Avg_Salary_Diff
# 7  Hannah   89735                 11541.8
# 4     Eve   97221                 19027.8
# 5   Frank   94820                 16626.8
# 3   David   71090                 -7103.2
# 6   Grace   30769                -47424.2

# %%
#  Find employees with a rating higher than the mean rating in their department and display their names and ratings.

df[df['Rating'] > df.groupby('Department')['Rating'].transform('mean')][['Name', 'Rating']]
# Out:
#      Name  Rating
# 3   David     2.2
# 4     Eve     3.1
# 5   Frank     2.7
# 6   Grace     2.2
# 7  Hannah     3.4
# 9    Jack     2.2

# %%
#  Group employees by department and calculate the minimum and maximum
# salary for each department, then filter departments where the maximum salary exceeds 95,000.

df.groupby('Department').agg({'Salary': ['min', 'max']}).loc[lambda x: x['Salary']['max'] > 95000]
# Out:
#            Salary
#               min    max
# Department
# Finance     46023  97221

# %%
#  Create a new column 'Age_Range' to categorize employees as 'Young', 'Mid
# Age', or 'Senior' based on their age, and then display the count of employees in each category.

df['Age_Range'] = pd.cut(df['Age'], bins=[18, 30, 45, 60], labels=['Young', 'Mid-Age', 'Senior'])
df.head()
# Out:
#       Name  Age Gender  Salary Department  Join_Date  Rating  Dept_Avg_Salary  \
# 0    Alice   56      F   74131         HR 2020-01-31     1.8     67728.750000
# 1      Bob   46      M   90263         IT 2020-02-29     1.7     92679.333333
# 2  Charlie   32      M   46023    Finance 2020-03-31     1.7     77659.666667
# 3    David   25      M   71090         HR 2020-04-30     2.2     67728.750000
# 4      Eve   38      F   97221    Finance 2020-05-31     3.1     77659.666667
#
#    Years_Since_Joining  Salary_Per_Year_Of_Experience  Years_In_Company  \
# 0                    5                       14826.20                 5
# 1                    5                       18052.60                 5
# 2                    5                        9204.60                 5
# 3                    4                       17772.50                 4
# 4                    4                       24305.25                 4
#
# ...

# %%
df['Age_Range'] = pd.cut(df['Experience'], bins=[0, 30, 50, np.in],labels=['Young', 'Mid_Age', 'Senior'])
df['Age_Range'].value_counts()
# Out:
#   File "<ipython-input-90-cbbfeb0e1e13>", line 1
#     df['Age_Range'] = pd.cut(df['Experience'], bins=[0, 30, 50, np.in],labels=['Young', 'Mid_Age', 'Senior'])
#                                                                    ^
# SyntaxError: invalid syntax

# %%
#  Calculate the correlation between 'Salary' and 'Rating' and between 'Age' and 'Years_Since_Joining'.

df[['Salary', 'Rating']].corr(), df[['Age', 'Years_Since_Joining']].corr()
# Out:
# (          Salary    Rating
#  Salary  1.000000  0.326757
#  Rating  0.326757  1.000000,
#                            Age  Years_Since_Joining
#  Age                  1.000000             0.381039
#  Years_Since_Joining  0.381039             1.000000)

# %%
# For each gender and department, calculate the percentage of employees with a salary above 50,000.

df['HighSalary'] = df['Salary'] > 50000


percentage = df.groupby(['Gender', 'Department','Salary'])['HighSalary'].mean() * 100

percentage = percentage.reset_index().rename(columns={'HighSalary': 'Percentage >50K'})

percentage
# Out:
#   Gender Department  Salary  Percentage >50K
# 0      F    Finance   89735            100.0
# 1      F    Finance   97221            100.0
# 2      F         HR   30769              0.0
# 3      F         HR   74131            100.0
# 4      F         IT   92955            100.0
# 5      M    Finance   46023              0.0
# 6      M         HR   71090            100.0
# 7      M         HR   94925            100.0
# 8      M         IT   90263            100.0
# 9      M         IT   94820            100.0

# %%
#  For each employee, calculate the ratio of their salary to their years since joining, and filter those with a ratio above 20,000.

df['Salary_Years_Ratio'] = df['Salary'] / df['Years_Since_Joining']
df[df['Salary_Years_Ratio'] > 20000]
# Out:
#      Name  Age Gender  Salary Department  Join_Date  Rating  Dept_Avg_Salary  \
# 4     Eve   38      F   97221    Finance 2020-05-31     3.1     77659.666667
# 5   Frank   56      M   94820         IT 2020-06-30     2.7     92679.333333
# 7  Hannah   40      F   89735    Finance 2020-08-31     3.4     77659.666667
# 8     Ivy   28      F   92955         IT 2020-09-30     1.6     92679.333333
# 9    Jack   28      M   94925         HR 2020-10-31     2.2     67728.750000
#
#    Years_Since_Joining  Salary_Per_Year_Of_Experience  Years_In_Company  \
# 4                    4                       24305.25                 4
# 5                    4                       23705.00                 4
# 7                    4                       22433.75                 4
# 8                    4                       23238.75                 4
# 9                    4                       23731.25                 4
#
# ...

# %%
# Group employees by 'Gender' and 'Department' to calculate the average salary,
#total salary, and count of employees. Then filter groups where the average salary exceeds 70,000.

df.groupby(['Gender', 'Department']).agg({'Salary': ['mean', 'sum', 'count']}).loc[lambda x: x['Salary']['mean'] > 70000]
# Out:
#                     Salary
#                       mean     sum count
# Gender Department
# F      Finance     93478.0  186956     2
#        IT          92955.0   92955     1
# M      HR          83007.5  166015     2
#        IT          92541.5  185083     2

# %%
df.groupby(['Gender', 'Department'])['Salary'].agg(['mean', 'sum','count']).query('mean > 70000')
# Out:
#                       mean     sum  count
# Gender Department
# F      Finance     93478.0  186956      2
#        IT          92955.0   92955      1
# M      HR          83007.5  166015      2
#        IT          92541.5  185083      2

# %%
 #Create a column 'Experience_Level' based on 'Years_Since_Joining',
#categorizing employees with less than 3 years as 'Junior', between 3-7 years as 'Mid',
# and more than 7 years as 'Senior'. Then display the count of employees in each category.

df['Experience_Level'] = pd.cut(df['Years_Since_Joining'], bins=[0, 3, 7, np.inf], labels=['Junior', 'Mid', 'Senior'])
df['Experience_Level'].value_counts()
# Out:
# Experience_Level
# Mid       10
# Junior     0
# Senior     0
# Name: count, dtype: int64

# %%
# Sort employees by their 'Join_Date' and calculate the cumulative salary for each department, then display the first 5 rows
df.sort_values(by = 'Join_Date').groupby('Department')['Salary'].cumsum().head()
df.sort_values(by = 'Join_Date').groupby('Department')['Salary'].cumsum().head()
# Out:
# 0     74131
# 1     90263
# 2     46023
# 3    145221
# 4    143244
# Name: Salary, dtype: int64

# %%
#  Display employees with the top 5 highest 'Salary_Per_Year' (salary divided by years since joining)
# and show their names, salaries, and ratios.
df['Salary_Per_Year'] = df['Salary'] / df['Years_Since_Joining']
df.nlargest(5, 'Salary_Per_Year')[['Name', 'Salary', 'Salary_Per_Year']]
# Out:
#      Name  Salary  Salary_Per_Year
# 4     Eve   97221         24305.25
# 9    Jack   94925         23731.25
# 5   Frank   94820         23705.00
# 8     Ivy   92955         23238.75
# 7  Hannah   89735         22433.75

# %%
#  Calculate the mean rating for each department and filter employees whose
# rating is greater than their department's average rating.



dept_avg = df.groupby('Department')['Rating'].transform('mean')

# Step 2: Filter employees with rating > department average
df[df['Rating'] > dept_avg]
# Out:
#      Name  Age Gender  Salary Department  Join_Date  Rating  Dept_Avg_Salary  \
# 3   David   25      M   71090         HR 2020-04-30     2.2     67728.750000
# 4     Eve   38      F   97221    Finance 2020-05-31     3.1     77659.666667
# 5   Frank   56      M   94820         IT 2020-06-30     2.7     92679.333333
# 6   Grace   36      F   30769         HR 2020-07-31     2.2     67728.750000
# 7  Hannah   40      F   89735    Finance 2020-08-31     3.4     77659.666667
# 9    Jack   28      M   94925         HR 2020-10-31     2.2     67728.750000
#
#    Years_Since_Joining  Salary_Per_Year_Of_Experience  Years_In_Company  \
# 3                    4                       17772.50                 4
# 4                    4                       24305.25                 4
# 5                    4                       23705.00                 4
# 6                    4                        7692.25                 4
# ...

# %%
# Step 1: Get department-wise average ratings
dept_avg = df.groupby('Department', as_index=False)['Rating'].mean()
dept_avg = dept_avg.rename(columns={'Rating': 'Dept_Avg_Rating'})

# Step 2: Merge back to original DataFrame
merged = df.merge(dept_avg, on='Department')

# Step 3: Filter where employee's rating > department average
result = merged[merged['Rating'] > merged['Dept_Avg_Rating']]
result
# Out:
#      Name  Age Gender  Salary Department  Join_Date  Rating  Dept_Avg_Salary  \
# 3   David   25      M   71090         HR 2020-04-30     2.2     67728.750000
# 4     Eve   38      F   97221    Finance 2020-05-31     3.1     77659.666667
# 5   Frank   56      M   94820         IT 2020-06-30     2.7     92679.333333
# 6   Grace   36      F   30769         HR 2020-07-31     2.2     67728.750000
# 7  Hannah   40      F   89735    Finance 2020-08-31     3.4     77659.666667
# 9    Jack   28      M   94925         HR 2020-10-31     2.2     67728.750000
#
#    Years_Since_Joining  Salary_Per_Year_Of_Experience  Years_In_Company  \
# 3                    4                       17772.50                 4
# 4                    4                       24305.25                 4
# 5                    4                       23705.00                 4
# 6                    4                        7692.25                 4
# ...

# %%
#  Group employees by 'Department' and calculate the maximum, minimum, and mean salary.
# Then display departments where the maximum salary is greater than 90,000.
df.groupby('Department').agg({'Salary' : ['max','min','mean']}).loc[lambda x: x['Salary']['max'] > 90000]
# Out:
#            Salary
#               max    min          mean
# Department
# Finance     97221  46023  77659.666667
# HR          94925  30769  67728.750000
# IT          94820  90263  92679.333333

# %%
salary_stats = df.groupby('Department').agg({'Salary': ['max', 'min', 'mean']})

filtered = salary_stats.loc[salary_stats[('Salary', 'max')] > 90000]
filtered
# Out:
#            Salary
#               max    min          mean
# Department
# Finance     97221  46023  77659.666667
# HR          94925  30769  67728.750000
# IT          94820  90263  92679.333333

# %%
df.groupby(['Department'])['Salary'].agg(['max', 'min','mean']).rename(columns={'max':'max_salary'}).query("max_salary > 90000")
# Out:
#             max_salary    min          mean
# Department
# Finance          97221  46023  77659.666667
# HR               94925  30769  67728.750000
# IT               94820  90263  92679.333333

# %%
#Create a new column 'Salary_Per_Age' by dividing salary by age, then find and display the top 5 employees with the highest values.

df['Salary_Per_Age'] = df['Salary'] / df['Age'].round(2)
df.nlargest(5, 'Salary_Per_Age')
# Out:
#      Name  Age Gender  Salary Department  Join_Date  Rating  Dept_Avg_Salary  \
# 9    Jack   28      M   94925         HR 2020-10-31     2.2     67728.750000
# 8     Ivy   28      F   92955         IT 2020-09-30     1.6     92679.333333
# 3   David   25      M   71090         HR 2020-04-30     2.2     67728.750000
# 4     Eve   38      F   97221    Finance 2020-05-31     3.1     77659.666667
# 7  Hannah   40      F   89735    Finance 2020-08-31     3.4     77659.666667
#
#    Years_Since_Joining  Salary_Per_Year_Of_Experience  Years_In_Company  \
# 9                    4                       23731.25                 4
# 8                    4                       23238.75                 4
# 3                    4                       17772.50                 4
# 4                    4                       24305.25                 4
# 7                    4                       22433.75                 4
#
# ...

# %%
#  Create a pivot table to show the average salary and total salary for each combination of 'Department' and 'Gender'.
pd.pivot_table(df, index='Gender', columns='Department', values='Salary', aggfunc=['mean', 'sum'])
# Out:
#                mean                       sum
# Department  Finance       HR       IT Finance      HR      IT
# Gender
# F           93478.0  52450.0  92955.0  186956  104900   92955
# M           46023.0  83007.5  92541.5   46023  166015  185083

# %%
# Calculate the rolling mean salary over a window of 4 employees sorted by 'Join_Date', then display the first 10 results.


df.sort_values(by='Join_Date')['Salary'].rolling(window=4).mean().head(10)
# Out:
# 0         NaN
# 1         NaN
# 2         NaN
# 3    70376.75
# 4    76149.25
# 5    77288.50
# 6    73475.00
# 7    78136.25
# 8    77069.75
# 9    77096.00
# Name: Salary, dtype: float64

# %%
df['Rolling_mean']=df.sort_values(by='Join_Date') ['Salary'].rolling(window=4).mean()
df.nlargest(10, 'Rolling_mean')
# Out:
#       Name  Age Gender  Salary Department  Join_Date  Rating  Dept_Avg_Salary  \
# 7   Hannah   40      F   89735    Finance 2020-08-31     3.4     77659.666667
# 5    Frank   56      M   94820         IT 2020-06-30     2.7     92679.333333
# 9     Jack   28      M   94925         HR 2020-10-31     2.2     67728.750000
# 8      Ivy   28      F   92955         IT 2020-09-30     1.6     92679.333333
# 4      Eve   38      F   97221    Finance 2020-05-31     3.1     77659.666667
# 6    Grace   36      F   30769         HR 2020-07-31     2.2     67728.750000
# 3    David   25      M   71090         HR 2020-04-30     2.2     67728.750000
# 0    Alice   56      F   74131         HR 2020-01-31     1.8     67728.750000
# 1      Bob   46      M   90263         IT 2020-02-29     1.7     92679.333333
# 2  Charlie   32      M   46023    Finance 2020-03-31     1.7     77659.666667
#
#    Years_Since_Joining  Salary_Per_Year_Of_Experience  ...  \
# ...

# %%
#  Create a new column 'Rating_Age_Ratio' as the ratio of 'Rating' to 'Age', then
# find the employee with the highest ratio and display their name and ratio.

df['Rating_Age_Ratio'] = df['Rating'] / df['Age']
df.nlargest(1, 'Rating_Age_Ratio')[['Name','Age','Rating_Age_Ratio']]
# Out:
#     Name  Age  Rating_Age_Ratio
# 3  David   25             0.088

# %%
# Hard Questions
# Q81: Find the top 3 highest-paid employees from each department.


df.groupby('Department').apply(lambda x:x.nlargest(3, 'Salary'))
# Out:
# <ipython-input-167-6bb637faae64>:5: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df.groupby('Department').apply(lambda x:x.nlargest(3, 'Salary'))
#                  Name  Age Gender  Salary Department  Join_Date  Rating  \
# Department
# Finance    4      Eve   38      F   97221    Finance 2020-05-31     3.1
#            7   Hannah   40      F   89735    Finance 2020-08-31     3.4
#            2  Charlie   32      M   46023    Finance 2020-03-31     1.7
# HR         9     Jack   28      M   94925         HR 2020-10-31     2.2
#            0    Alice   56      F   74131         HR 2020-01-31     1.8
#            3    David   25      M   71090         HR 2020-04-30     2.2
# ...

# %%
#  Create a pivot table showing the mean salary and mean rating for each combination of department and gender

pd.pivot_table(df, index='Gender', columns='Department', values=['Salary', 'Rating'], aggfunc=['mean'])
# Out:
#               mean
#             Rating             Salary
# Department Finance   HR   IT  Finance       HR       IT
# Gender
# F             3.25  2.0  1.6  93478.0  52450.0  92955.0
# M             1.70  2.2  2.2  46023.0  83007.5  92541.5

# %%
#  Calculate the cumulative salary of employees in the DataFrame and add it as a new column.
df['Cum_Salary'] = df.groupby('Department')['Salary'].cumsum()
df
# Out:
#       Name  Age Gender  Salary Department  Join_Date  Rating  Dept_Avg_Salary  \
# 0    Alice   56      F   74131         HR 2020-01-31     1.8     67728.750000
# 1      Bob   46      M   90263         IT 2020-02-29     1.7     92679.333333
# 2  Charlie   32      M   46023    Finance 2020-03-31     1.7     77659.666667
# 3    David   25      M   71090         HR 2020-04-30     2.2     67728.750000
# 4      Eve   38      F   97221    Finance 2020-05-31     3.1     77659.666667
# 5    Frank   56      M   94820         IT 2020-06-30     2.7     92679.333333
# 6    Grace   36      F   30769         HR 2020-07-31     2.2     67728.750000
# 7   Hannah   40      F   89735    Finance 2020-08-31     3.4     77659.666667
# 8      Ivy   28      F   92955         IT 2020-09-30     1.6     92679.333333
# 9     Jack   28      M   94925         HR 2020-10-31     2.2     67728.750000
#
#    Years_Since_Joining  Salary_Per_Year_Of_Experience  ...  \
# ...

# %%
df['Cumulative_Salary'] = df['Salary'].cumsum()
df.head()
# Out:
#       Name  Age Gender  Salary Department  Join_Date  Rating  Dept_Avg_Salary  \
# 0    Alice   56      F   74131         HR 2020-01-31     1.8     67728.750000
# 1      Bob   46      M   90263         IT 2020-02-29     1.7     92679.333333
# 2  Charlie   32      M   46023    Finance 2020-03-31     1.7     77659.666667
# 3    David   25      M   71090         HR 2020-04-30     2.2     67728.750000
# 4      Eve   38      F   97221    Finance 2020-05-31     3.1     77659.666667
#
#    Years_Since_Joining  Salary_Per_Year_Of_Experience  ...  Age_Range  \
# 0                    5                       14826.20  ...     Senior
# 1                    5                       18052.60  ...     Senior
# 2                    5                        9204.60  ...    Mid-Age
# 3                    4                       17772.50  ...      Young
# 4                    4                       24305.25  ...    Mid-Age
#
#    HighSalary  Salary_Years_Ratio  Experience_Level Salary_Per_Year  \
# ...

# %%
# Create a new column 'Salary_Per_Year' by dividing the salary by the number of years since joining.
df['Salary_Per_Year'] = df['Salary'] / df['Years_Since_Joining']
df.head()
# Out:
#       Name  Age Gender  Salary Department  Join_Date  Rating  Dept_Avg_Salary  \
# 0    Alice   56      F   74131         HR 2020-01-31     1.8     67728.750000
# 1      Bob   46      M   90263         IT 2020-02-29     1.7     92679.333333
# 2  Charlie   32      M   46023    Finance 2020-03-31     1.7     77659.666667
# 3    David   25      M   71090         HR 2020-04-30     2.2     67728.750000
# 4      Eve   38      F   97221    Finance 2020-05-31     3.1     77659.666667
#
#    Years_Since_Joining  Salary_Per_Year_Of_Experience  ...  Age_Range  \
# 0                    5                       14826.20  ...     Senior
# 1                    5                       18052.60  ...     Senior
# 2                    5                        9204.60  ...    Mid-Age
# 3                    4                       17772.50  ...      Young
# 4                    4                       24305.25  ...    Mid-Age
#
#    HighSalary  Salary_Years_Ratio  Experience_Level Salary_Per_Year  \
# ...

# %%
# : Filter employees whose name contains the letter 'a' and who joined after 2020, then sort by age.

df[df['Name'].str.contains('a') & (df['Join_Date'].dt.year > 2020)].sort_values(by='Age')
# Out:
# Empty DataFrame
# Columns: [Name, Age, Gender, Salary, Department, Join_Date, Rating, Dept_Avg_Salary, Years_Since_Joining, Salary_Per_Year_Of_Experience, Years_In_Company, Years_Till_Retirement, Diff_Avg_Salary, Salary_Avg_Salary_Diff, Age_Range, HighSalary, Salary_Years_Ratio, Experience_Level, Salary_Per_Year, Salary_Per_Age, Rolling_mean, Rating_Age_Ratio, Cum_Salary, Cumulative_Salary]
# Index: []
#
# [0 rows x 24 columns]

# %%
df[(df['Name'].str.contains('a')) & (df['Join_Date'] > '2020-01-31')].sort_values(by='Age')
# Out:
#       Name  Age Gender  Salary Department  Join_Date  Rating  Dept_Avg_Salary  \
# 3    David   25      M   71090         HR 2020-04-30     2.2     67728.750000
# 9     Jack   28      M   94925         HR 2020-10-31     2.2     67728.750000
# 2  Charlie   32      M   46023    Finance 2020-03-31     1.7     77659.666667
# 6    Grace   36      F   30769         HR 2020-07-31     2.2     67728.750000
# 7   Hannah   40      F   89735    Finance 2020-08-31     3.4     77659.666667
# 5    Frank   56      M   94820         IT 2020-06-30     2.7     92679.333333
#
#    Years_Since_Joining  Salary_Per_Year_Of_Experience  ...  Age_Range  \
# 3                    4                       17772.50  ...      Young
# 9                    4                       23731.25  ...      Young
# 2                    5                        9204.60  ...    Mid-Age
# 6                    4                        7692.25  ...    Mid-Age
# 7                    4                       22433.75  ...    Mid-Age
# ...

# %%
#  For each employee, calculate their percentage contribution to the total salary in their department, and display the first 5 rows
df['Dept_Total_Salary'] = df.groupby('Department')['Salary'].transform('sum')
df['Salary_Contribution'] = (df['Salary'] / df['Dept_Total_Salary']) * 100
df[['Name', 'Department', 'Salary', 'Dept_Total_Salary', 'Salary_Contribution']]
# Out:
#       Name Department  Salary  Dept_Total_Salary  Salary_Contribution
# 0    Alice         HR   74131             270915            27.363195
# 1      Bob         IT   90263             278038            32.464267
# 2  Charlie    Finance   46023             232979            19.754141
# 3    David         HR   71090             270915            26.240703
# 4      Eve    Finance   97221             232979            41.729512
# 5    Frank         IT   94820             278038            34.103252
# 6    Grace         HR   30769             270915            11.357437
# 7   Hannah    Finance   89735             232979            38.516347
# 8      Ivy         IT   92955             278038            33.432480
# 9     Jack         HR   94925             270915            35.038665

# %%
# : Create a pivot table that shows the average salary and rating for each combination of department and gender

pd.pivot_table(df, index='Gender', columns='Department', values=['Salary','Rating'], aggfunc='mean')
# Out:
#             Rating             Salary
# Department Finance   HR   IT  Finance       HR       IT
# Gender
# F             3.25  2.0  1.6  93478.0  52450.0  92955.0
# M             1.70  2.2  2.2  46023.0  83007.5  92541.5

# %%
# Display the top 3 employees in terms of salary for each department, including their names and salaries

df.groupby('Department').apply(lambda x: x.nlargest(3, 'Salary')) [['Name', 'Salary']]
# Out:
# <ipython-input-186-818ecfc06157>:3: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df.groupby('Department').apply(lambda x: x.nlargest(3, 'Salary')) [['Name', 'Salary']]
#                  Name  Salary
# Department
# Finance    4      Eve   97221
#            7   Hannah   89735
#            2  Charlie   46023
# HR         9     Jack   94925
#            0    Alice   74131
#            3    David   71090
# IT         5    Frank   94820
#            8      Ivy   92955
#            1      Bob   90263

# %%
#  Calculate the cumulative sum of salaries within each department and create a new column 'Cumulative_Salary'.
# Display the first 5 rows.
df['Cumulative_Salary'] = df.groupby('Department')['Salary'].cumsum()
df.head()
# Out:
#       Name  Age Gender  Salary Department  Join_Date  Rating  Dept_Avg_Salary  \
# 0    Alice   56      F   74131         HR 2020-01-31     1.8     67728.750000
# 1      Bob   46      M   90263         IT 2020-02-29     1.7     92679.333333
# 2  Charlie   32      M   46023    Finance 2020-03-31     1.7     77659.666667
# 3    David   25      M   71090         HR 2020-04-30     2.2     67728.750000
# 4      Eve   38      F   97221    Finance 2020-05-31     3.1     77659.666667
#
#    Years_Since_Joining  Salary_Per_Year_Of_Experience  ...  \
# 0                    5                       14826.20  ...
# 1                    5                       18052.60  ...
# 2                    5                        9204.60  ...
# 3                    4                       17772.50  ...
# 4                    4                       24305.25  ...
#
#    Salary_Years_Ratio  Experience_Level  Salary_Per_Year  Salary_Per_Age  \
# ...

# %%
#  Display employees who are in the top 20% by age and have a rating above 2.5

df['Top_20%_By_Age'] = df['Age'].quantile(0.8)
df[(df['Rating'] > 2.5) & (df['Top_20%_By_Age'])]
# Out:
#      Name  Age Gender  Salary Department  Join_Date  Rating  Dept_Avg_Salary  \
# 4     Eve   38      F   97221    Finance 2020-05-31     3.1     77659.666667
# 5   Frank   56      M   94820         IT 2020-06-30     2.7     92679.333333
# 7  Hannah   40      F   89735    Finance 2020-08-31     3.4     77659.666667
#
#    Years_Since_Joining  Salary_Per_Year_Of_Experience  ...  Experience_Level  \
# 4                    4                       24305.25  ...               Mid
# 5                    4                       23705.00  ...               Mid
# 7                    4                       22433.75  ...               Mid
#
#    Salary_Per_Year  Salary_Per_Age  Rolling_mean Rating_Age_Ratio  Cum_Salary  \
# 4         24305.25     2558.447368      76149.25         0.081579      143244
# 5         23705.00     1693.214286      77288.50         0.048214      185083
# 7         22433.75     2243.375000      78136.25         0.085000      232979
#
# ...

# %%
# For each department, calculate the mean salary, standard deviation of salaries,
# and the number of employees. Then filter departments where the mean salary
# exceeds 60,000 and the standard deviation is less than 10,000.
df.groupby('Department').agg({'Salary':['mean','std','count']}).loc[lambda x: x['Salary']['mean'] > 60000 & (x['Salary']['std'] < 10000)]
# Out:
#                   Salary
#                     mean           std count
# Department
# Finance     77659.666667  27652.650096     3
# HR          67728.750000  26820.054317     4
# IT          92679.333333   2290.972792     3

# %%
df.groupby('Department')['Salary'].agg(['mean', 'std','count']).query('mean > 60000 & std < 10000')
# Out:
#                     mean          std  count
# Department
# IT          92679.333333  2290.972792      3

# %%
# Find the employee(s) with the highest 'Salary_Per_Year' ratio for each department and display their name, salary, and ratio
df.groupby('Department').apply(lambda x: x.nlargest(1, 'Salary_Per_Year'))[['Name', 'Salary', 'Salary_Per_Year']]
# Out:
# <ipython-input-207-db0f7edb8229>:2: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df.groupby('Department').apply(lambda x: x.nlargest(1, 'Salary_Per_Year'))[['Name', 'Salary', 'Salary_Per_Year']]
#                Name  Salary  Salary_Per_Year
# Department
# Finance    4    Eve   97221         24305.25
# HR         9   Jack   94925         23731.25
# IT         5  Frank   94820         23705.00

# %%
# Create a pivot table showing the average salary and total salary for each combination of department and gender.
df.groupby(['Gender', 'Department'])['Salary'].agg(['mean', 'sum'])
# Out:
#                       mean     sum
# Gender Department
# F      Finance     93478.0  186956
#        HR          52450.0  104900
#        IT          92955.0   92955
# M      Finance     46023.0   46023
#        HR          83007.5  166015
#        IT          92541.5  185083

# %%
# Calculate the rolling mean of salaries over a window of 5 employees, sorted by 'Join_Date', and display the first 10 results
df.sort_values(by='Join_Date')['Salary'].rolling(window=5).mean().head(10)
# Out:
# 0        NaN
# 1        NaN
# 2        NaN
# 3        NaN
# 4    75745.6
# 5    79883.4
# 6    67984.6
# 7    76727.0
# 8    81100.0
# 9    80640.8
# Name: Salary, dtype: float64

# %%
#  Create a new column 'Salary_to_Age_Ratio' by dividing the salary by age, and then find the employee with the highest ratio
df['Salary_to_Age_Ratio'] = df['Salary'] / df['Age']
df.nlargest(1, 'Salary_to_Age_Ratio')
# Out:
#    Name  Age Gender  Salary Department  Join_Date  Rating  Dept_Avg_Salary  \
# 9  Jack   28      M   94925         HR 2020-10-31     2.2         67728.75
#
#    Years_Since_Joining  Salary_Per_Year_Of_Experience  ...  Salary_Per_Year  \
# 9                    4                       23731.25  ...         23731.25
#
#    Salary_Per_Age  Rolling_mean  Rating_Age_Ratio Cum_Salary  \
# 9     3390.178571       77096.0          0.078571     270915
#
#    Cumulative_Salary  Dept_Total_Salary Salary_Contribution  Top_20%_By_Age  \
# 9             270915             270915           35.038665            48.0
#
#    Salary_to_Age_Ratio
# 9          3390.178571
#
# [1 rows x 28 columns]

# %%
#  Display the names and salaries of the bottom 10% of employees by salary, and calculate the total salary of these employees
df.nsmallest(int(0.1 * len(df)), 'Salary')['Salary'].sum()
# Out:
# np.int64(30769)

# %%
# For each employee, calculate their percentage contribution to the total salary in their department and
# display the first 10 rows with 'Name', 'Department', and 'Salary_Contribution'.

df[['Name', 'Department', 'Salary', 'Salary_Contribution',]]
# Out:
#       Name Department  Salary  Salary_Contribution
# 0    Alice         HR   74131            27.363195
# 1      Bob         IT   90263            32.464267
# 2  Charlie    Finance   46023            19.754141
# 3    David         HR   71090            26.240703
# 4      Eve    Finance   97221            41.729512
# 5    Frank         IT   94820            34.103252
# 6    Grace         HR   30769            11.357437
# 7   Hannah    Finance   89735            38.516347
# 8      Ivy         IT   92955            33.432480
# 9     Jack         HR   94925            35.038665

# %%
#  Calculate the ratio of each employee's salary to the average salary in their department, and
# filter employees with a ratio greater than 1.2

df['Dept_Avg_Salary'] = df.groupby('Department') ['Salary'].transform('mean')

Salary_Dept_Avg_Salary_Ratio = df['Salary'] / df['Dept_Avg_Salary']

Salary_Dept_Avg_Salary_Ratio[Salary_Dept_Avg_Salary_Ratio > 1.2]
# Out:
# 4    1.251885
# 9    1.401547
# dtype: float64

# %%
#  Create a rolling window of 5 employees based on their 'Join_Date', and for each window, calculate the average age and display the results.
df.sort_values(by='Join_Date')['Age'].rolling(window=5).mean()
# Out:
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 4    39.4
# 5    39.4
# 6    37.4
# 7    39.0
# 8    39.6
# 9    37.6
# Name: Age, dtype: float64

# %%
 #Group employees by 'Department' and calculate the mean, standard deviation, and total salary.
 # Filter departments where the mean salary is greater than 60,000 and the standard deviation is less than 12,000.

 df.groupby('Department').agg({'Salary': ['mean', 'std', 'sum']}).loc[lambda x: x['Salary']['mean'] > 60000 & (x['Salary']['std'] < 12000)]
#
# Out:
#                   Salary
#                     mean           std     sum
# Department
# Finance     77659.666667  27652.650096  232979
# HR          67728.750000  26820.054317  270915
# IT          92679.333333   2290.972792  278038

# %%
df.groupby('Department')['Salary'].agg(['mean', 'std', 'sum']).query('mean > 60000 & std > 12000')
# Out:
#                     mean           std     sum
# Department
# Finance     77659.666667  27652.650096  232979
# HR          67728.750000  26820.054317  270915

# %%
#  For each department, find the employee with the highest 'Salary_Per_Year' ratio and display their name, department, and salary.
df.nlargest(1, 'Salary_Per_Year')[['Name', 'Department', 'Salary']]
# Out:
#   Name Department  Salary
# 4  Eve    Finance   97221

# %%
# : Calculate the percentage of employees in each gender within each department who earn more than 50,000
df['HighSalary'] = df['Salary'] > 50000
df.groupby(['Gender', 'Department'])['HighSalary'].mean() * 100
# Out:
# Gender  Department
# F       Finance       100.0
#         HR             50.0
#         IT            100.0
# M       Finance         0.0
#         HR            100.0
#         IT            100.0
# Name: HighSalary, dtype: float64

# %%
#  Calculate the rolling mean of 'Rating' over a window of 5 employees sorted by 'Join_Date', and display the top 5 results.
df.sort_values(by='Join_Date')['Rating'].rolling(window=5).mean().head()
# Out:
# 0    NaN
# 1    NaN
# 2    NaN
# 3    NaN
# 4    2.1
# Name: Rating, dtype: float64

# %%
# For each employee, calculate the percentage contribution of their salary to the total salary of their department, and display the first 10 rows.
df['Salary_Contribution'] = (df['Salary'] / df['Dept_Total_Salary']) * 100
df[['Name', 'Department', 'Salary', 'Dept_Total_Salary', 'Salary_Contribution']].head(10)
# Out:
#       Name Department  Salary  Dept_Total_Salary  Salary_Contribution
# 0    Alice         HR   74131             270915            27.363195
# 1      Bob         IT   90263             278038            32.464267
# 2  Charlie    Finance   46023             232979            19.754141
# 3    David         HR   71090             270915            26.240703
# 4      Eve    Finance   97221             232979            41.729512
# 5    Frank         IT   94820             278038            34.103252
# 6    Grace         HR   30769             270915            11.357437
# 7   Hannah    Finance   89735             232979            38.516347
# 8      Ivy         IT   92955             278038            33.432480
# 9     Jack         HR   94925             270915            35.038665

# %%
# : Identify the top 2 departments with the highest total salary, and display their total salary and employee count.
df.groupby('Department').agg({'Salary':'sum','Name':'count'}).nlargest(2, 'Salary')
# Out:
#             Salary  Name
# Department
# IT          278038     3
# HR          270915     4

# %%
#  Calculate the ratio of each employee's salary to the average salary in their department, and filter employees with a ratio greater than 1.2.
df['Salary_Dept_Avg_Salary_Ratio'] = df['Salary'] / df['Dept_Avg_Salary']
df[df['Salary_Dept_Avg_Salary_Ratio'] > 1.2]
# Out:
#    Name  Age Gender  Salary Department  Join_Date  Rating  Dept_Avg_Salary  \
# 4   Eve   38      F   97221    Finance 2020-05-31     3.1     77659.666667
# 9  Jack   28      M   94925         HR 2020-10-31     2.2     67728.750000
#
#    Years_Since_Joining  Salary_Per_Year_Of_Experience  ...  Salary_Per_Age  \
# 4                    4                       24305.25  ...     2558.447368
# 9                    4                       23731.25  ...     3390.178571
#
#    Rolling_mean  Rating_Age_Ratio  Cum_Salary Cumulative_Salary  \
# 4      76149.25          0.081579      143244            143244
# 9      77096.00          0.078571      270915            270915
#
#    Dept_Total_Salary  Salary_Contribution Top_20%_By_Age  Salary_to_Age_Ratio  \
# 4             232979            41.729512           48.0          2558.447368
# 9             270915            35.038665           48.0          3390.178571
#
#    Salary_Dept_Avg_Salary_Ratio
# 4                      1.251885
# ...

# %%
# Create a pivot table that shows the count of employees and the mean salary, grouped by both 'Department' and 'Gender'.
pd.pivot_table(df, index='Gender', columns='Department', values='Salary', aggfunc=['mean', 'count'])
# Out:
#                mean                     count
# Department  Finance       HR       IT Finance HR IT
# Gender
# F           93478.0  52450.0  92955.0       2  2  1
# M           46023.0  83007.5  92541.5       1  2  2

# %%
#  Calculate the rolling mean of 'Age' over a window of 5 employees based on their 'Join_Date', and display the results.

df.sort_values(by= 'Join_Date' )[ 'Age' ].rolling(window=5).mean()
# Out:
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 4    39.4
# 5    39.4
# 6    37.4
# 7    39.0
# 8    39.6
# 9    37.6
# Name: Age, dtype: float64
